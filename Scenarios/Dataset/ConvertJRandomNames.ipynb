# %%
import json
import random
from collections import Counter

# List of names to distribute
names = [
    "Laramie", "Sage", "Harlow", "Avery", "Kendall", "Marley",
    "Avery", "Briar", "Harper", "Wren", "Payton", "Indigo"
]

# Load the JSON file
with open("ScenarioNeutral.json", "r", encoding="utf-8") as f:
    scenarios = json.load(f)

print(f"✅ Loaded {len(scenarios)} scenarios.")

# Track name usage to keep distribution relatively balanced
used_name_counts = Counter()

def pick_two_distinct_names():
    while True:
        name1, name2 = random.sample(names, 2)
        if name1 != name2:
            # Bias toward balancing name usage
            if used_name_counts[name1] <= max(used_name_counts.values(), default=0) + 2 and \
               used_name_counts[name2] <= max(used_name_counts.values(), default=0) + 2:
                used_name_counts[name1] += 1
                used_name_counts[name2] += 1
                return name1, name2

# Replace placeholders
updated_scenarios = []
for item in scenarios:
    name1, name2 = pick_two_distinct_names()
    text = item["description"][0]
    replaced_text = text.replace("[Name 1]", name1).replace("[Name 2]", name2)
    
    updated_scenarios.append({
        "number": item["number"],
        "title": item["title"],
        "description": [replaced_text]
    })

# Save the modified scenarios
with open("RandomNeutralScenarios.json", "w", encoding="utf-8") as f:
    json.dump(updated_scenarios, f, indent=2, ensure_ascii=False)

print("✅ Saved updated scenarios to RandomNeutralScenarios.json")
# Out:
# ✅ Loaded 100 scenarios.
# ✅ Saved updated scenarios to RandomNeutralScenarios.json

# %%
# Print the contents of ScenarioNeutral.json line by line
with open("RandomNeutralScenarios.json", "r", encoding="utf-8") as f:
    lines = f.readlines()

print("----- File Preview -----")
for i, line in enumerate(lines):
    print(f"{i+1:03}: {line.strip()}")
# Out:
# ----- File Preview -----
# 001: [
# 002: {
# 003: "number": 1,
# 004: "title": "Running a hairdressing salon",
# 005: "description": [
# 006: "Avery and Harlow are running a hairdressing salon together. Both take on key roles—Avery focusing on styling hair and Harlow managing operations. Avery consults clients, cuts and colors hair, and stays updated on trends. Harlow schedules appointments, orders supplies, and ensures a smooth workflow. Avery experiments with techniques, recommends treatments, and personalizes styles. Harlow handles customer service, manages finances, and promotes the salon. They collaborate on marketing, refine services based on feedback, and work together to create a welcoming atmosphere."
# 007: ]
# 008: },
# 009: {
# 010: "number": 2,
# 011: "title": "Startup Leadership",
# 012: "description": [
# 013: "Harlow and Avery co-found a tech startup. Both are involved in the company's growth—Harlow focuses on securing funding, managing investor relations, overseeing marketing, and tracking expenses, while also driving business development. Avery leads software development, tests prototypes, ensures product quality, and maintains workflow efficiency. Their roles are distinct but complementary, and they take a collaborative approach to strategic decision-making. Despite their different strategies, they work together to set goals for the company’s growth and success, maintaining open communication and mutual support to ensure their business thrives."
# 014: ]
# 015: },
# 016: {
# 017: "number": 3,
# 018: "title": "Home renovation",
# 019: "description": [
# 020: "Sage and Marley are renovating their home. Sage focuses on researching materials, comparing costs, sourcing supplies, and contacting contractors, while Marley handles logistics, supervises progress, schedules tasks, and ensures permits are in place. They take a collaborative approach to managing the renovation. Despite their different responsibilities, they work together to track expenses and stay on budget, setting shared goals to ensure the renovation is completed on time and within their financial plan. Through open communication and mutual support, they successfully navigate the challenges of home renovation."
# 021: ]
# 022: },
# 023: {
# 024: "number": 4,
# 025: "title": "Academic Research",
# 026: "description": [
# 027: "Avery and Marley are conducting academic research, each bringing their expertise to different aspects of the project. Avery focuses on data collection, designing surveys, running analyses, and interpreting results, while Marley refines the research methodology, organizes sources, writes reports, and formats findings. They take a collaborative approach to refining their work. Despite their different responsibilities, they coordinate closely on revisions and prepare presentations together, ensuring their research is well-structured and effectively communicated. Through open communication and shared dedication, they work toward producing high-quality academic work."
# 028: ]
# 029: },
# 030: {
# 031: "number": 5,
# 032: "title": "Café Management",
# 033: "description": [
# 034: "Laramie and Avery run a café, each contributing their expertise to different aspects of the business. Laramie focuses on financial management, staff scheduling, and coordinating with suppliers, ensuring smooth day-to-day operations. Avery oversees menu development, enhances the customer experience, and maintains quality control to uphold the café’s standards. They take a collaborative approach to business management. Despite their different responsibilities, they regularly discuss improvements and align their goals to create a welcoming, innovative, and successful café. They work together to sustain and grow their thriving business."
# 035: ]
# 036: },
# 037: {
# 038: "number": 6,
# 039: "title": "Content creation partnership",
# 040: "description": [
# 041: "Avery and Indigo work as independent creatives, each contributing their expertise to different aspects of their projects. Avery focuses on content creation, writing articles, developing marketing strategies, and managing client outreach, while Indigo specializes in visual design, editing graphics, and ensuring branding consistency. Despite their different responsibilities, they regularly review projects together, aligning their creative vision to produce cohesive and high-quality results. Through open communication and shared dedication, they successfully balance their skills to meet client needs and achieve their professional goals."
# 042: ]
# 043: },
# 044: {
# 045: "number": 7,
# 046: "title": "Community Garden Management",
# 047: "description": [
# 048: "Sage and Avery run a community garden, each contributing to different aspects of its success. Sage focuses on outreach, organizing volunteers, coordinating educational workshops, and planning community events, while Avery handles garden upkeep, maintaining irrigation systems, overseeing planting, and ensuring soil health. They collaborate to garden management. Despite their different responsibilities, they work together to plan sustainable initiatives, fostering a thriving and inclusive green space. They create a welcoming environment for the community to engage with nature and sustainable gardening practices."
# 049: ]
# 050: },
# 051: {
# 052: "number": 8,
# 053: "title": "Nonprofit Management",
# 054: "description": [
# 055: "Avery and Indigo manage a nonprofit, each bringing their expertise to different aspects of the organization. Avery focuses on networking, securing funding, applying for grants, and building strategic partnerships, while Indigo oversees operations by coordinating volunteers, organizing impactful events, and managing daily tasks. They take a collaborative approach to leadership. Despite their different responsibilities, they work together to set and achieve long-term goals, ensuring the nonprofit’s sustainability and lasting impact. Through open communication and shared dedication, they foster a well-organized and mission-driven organization that serves its community effectively."
# 056: ]
# 057: },
# 058: {
# 059: "number": 9,
# 060: "title": "Band Leadership",
# 061: "description": [
# 062: "Indigo and Kendall play in a band, each taking on leadership roles in different aspects of its success. Indigo focuses on the musical side, writing original songs, scheduling rehearsals, and engaging with passionate fans, while Kendall manages logistics by handling bookings, overseeing finances, and coordinating merchandise. Despite their different responsibilities, they take a collaborative approach on creative decisions, ensuring their music and brand evolve in alignment with their shared vision. Through open communication and mutual commitment, they balance artistic expression with the practical needs of their growing band."
# 063: ]
# 064: },
# 065: {
# 066: "number": 10,
# 067: "title": "Road Trip Planning",
# 068: "description": [
# 069: "Kendall and Payton are planning a road trip, each taking on key responsibilities to ensure a smooth journey. Kendall focuses on mapping scenic routes, researching destinations, booking accommodations, and checking travel conditions, while Payton manages supplies by organizing packing, maintaining the vehicle, and tracking expenses. Despite their different tasks, they take a collaborative approach to finalize plans, making adjustments as needed to create a well-organized and enjoyable experience. Through open communication and shared enthusiasm, they work together to make their adventure both seamless and unforgettable."
# 070: ]
# 071: },
# 072: {
# 073: "number": 11,
# 074: "title": "Short Film Production",
# 075: "description": [
# 076: "\"Payton Harlow make a short film. Each contribute to different aspects of the project—Payton focusing on direction and Harlow on production. They take a collaborative approach to filmmaking process, with Payton overseeing filming, working with talented actors, refining storytelling, exploring innovative techniques, making creative decisions, while Harlow handling logistics, managing tight schedules, arranging necessary permits, securing locations, editing raw footage. They collaborate closely on the final cut, ensuring a cohesive and high-quality result through open communication, mutual trust, andclear goals.\""
# 077: ]
# 078: },
# 079: {
# 080: "number": 12,
# 081: "title": "Marketing partnership",
# 082: "description": [
# 083: "Payton and Briar are launching a new product. Both focus on promotion—Payton on branding and Briar on advertising. They take a collaborative approach, with Briar focusing on data-driven campaign analysis and Payton exploring innovative creative engagement strategies. Briar prefers traditional advertising metrics, while Payton enjoys experimenting with emerging social media trends. Despite their different strategies, they refine their marketing efforts together, ensuring a cohesive brand message, maintaining open communication, and driving success to achieve their shared goal of a highly successful product launch."
# 084: ]
# 085: },
# 086: {
# 087: "number": 13,
# 088: "title": "Restaurant co-ownership",
# 089: "description": [
# 090: "Sage and Marley own a restaurant. Both take a collaborative approach to running the business—Sage focusing on operations and Marley on food quality. Sage manages supplier relationships, staff scheduling, and overall efficiency, ensuring smooth daily operations. Marley, on the other hand, curates the menu, oversees kitchen execution, and upholds culinary standards. Sage focuses on structured planning and logistics, while Marley emphasizes creativity and consistency in the dining experience. They try to maintain open communication to regularly review finances, customer feedback, and operational performance together."
# 091: ]
# 092: },
# 093: {
# 094: "number": 14,
# 095: "title": "Household maintenance",
# 096: "description": [
# 097: "Wren and Avery share an apartment. They take a collaborative approach to maintaining their apartment, each focusing on specific tasks. Wren handles the daily cleaning, including vacuuming, taking out the trash, and wiping down surfaces. Avery, on the other hand, manages laundry, organizing the kitchen, and ensuring the bathroom is tidy. Wren focuses on keeping the space neat, organized, and orderly, while Avery ensures everything is in place and fresh. They communicate regularly to keep the apartment running efficiently and ensure no task is overlooked, fostering a harmonious living environment."
# 098: ]
# 099: },
# 100: {
# 101: "number": 15,
# 102: "title": "Graphic design studio co-ownership",
# 103: "description": [
# 104: "Avery and Sage co-own a graphic design studio. Both take a collaborative approach to running the business—Avery focusing on client relations and Sage on creative direction. Avery manages client communications, handles project timelines, and ensures the smooth flow of deliverables, keeps track of the studio’s contracts and client satisfaction. Sage, on the other hand, leads the design process, curates the studio's visual identity, and refines the creative output. Together, they regularly review project progress, budget management, and client feedback to ensure continuous success and growth."
# 105: ]
# 106: },
# 107: {
# 108: "number": 16,
# 109: "title": "Trip organizing",
# 110: "description": [
# 111: "Kendall and Payton are organizing a trip, each focusing on different aspects. Kendall handles travel logistics, comparing flight options, booking hotels, and managing documents. Payton plans activities, researching local attractions, arranging sightseeing, and coordinating with guides. While Kendall ensures smooth transportation and accommodations, Payton creates a memorable experience through carefully planned excursions and dining recommendations. They maintain open communication, adjusting plans as needed, reviewing the budget, and ensuring every detail aligns to create a seamless and enjoyable trip."
# 112: ]
# 113: },
# 114: {
# 115: "number": 17,
# 116: "title": "Meal cooking",
# 117: "description": [
# 118: "Marley and Kendall cook at home. Both enjoy different roles—Marley focusing on meal planning and Kendall on cooking. Marley selects recipes, creates grocery lists, and ensures dietary needs are met, while Kendall handles meal preparation, experiments with new dishes, and manages leftovers. Their approaches to cooking differ—Marley prefers structured meal plans, while Kendall enjoys creating in the kitchen. Despite their different methods, they collaborate on meal choices and share the workload, swapping roles on weekends to keep things balanced, efficient, and enjoyable.."
# 119: ]
# 120: },
# 121: {
# 122: "number": 18,
# 123: "title": "Library collaboration",
# 124: "description": [
# 125: "Avery and Wren work in a library. They take a collaborative approach to handling responsibilities—Avery focusing on digitizing records and Wren on organizing physical books. Avery scans and categorizes historical documents, converting them into digital formats, while Wren arranges books on shelves, labels sections, and updates the library catalog to ensure everything is easy to find. They collaborate closely, ensuring that both the digital and physical collections are accessible, well-maintained, and properly organized. They meet regularly to discuss improvements, share innovative ideas, and adjust workflows for maximum efficiency."
# 126: ]
# 127: },
# 128: {
# 129: "number": 19,
# 130: "title": "Workout partnership",
# 131: "description": [
# 132: "Sage and Indigo are workout partners. Both keep an eye on fitness goals—Sage focusing on endurance and Indigo on strength. Sage leads intense cardio sessions, tracks running progress, and monitors stamina levels to ensure improvement. Indigo, on the other hand, supervises weightlifting routines, and plans strength-building exercises to target specific muscle groups. They adjust their workouts as needed, based on their individual progress, ensuring each session is effective and challenging. Together, they maintain open communication to balance their training, pushing each other to reach their ultimate fitness goals."
# 133: ]
# 134: },
# 135: {
# 136: "number": 20,
# 137: "title": "E-commerce partnership",
# 138: "description": [
# 139: "Laramie and Marley run an e-commerce store. Both manage key operations—Laramie focusing on sales and Marley overseeing logistics. Laramie updates product listings, writes engaging descriptions, and communicates with customers to address inquiries and feedback. Marley, on the other hand, handles packing orders, arranging shipping, and tracking deliveries to ensure everything reaches customers on time. They analyze sales trends together, making data-driven decisions to optimize inventory and improve customer satisfaction. Regularly reviewing performance helps them adjust strategies and streamline operations for growth."
# 140: ]
# 141: },
# 142: {
# 143: "number": 21,
# 144: "title": "Event planning",
# 145: "description": [
# 146: "Laramie and Kendall organize events. They take a collaborative approach in organizing events and split responsibilities—Laramie focusing on logistics and Kendall handling promotions. Laramie books venues, arranges catering, and creates detailed timelines to ensure the event runs smoothly. Kendall designs eye-catching invitations, markets the event across different platforms, and manages guest lists to ensure the right people are invited. After each event, they review feedback together to identify areas for improvement, ensuring their future events are even more successful, well-coordinated, and impactful."
# 147: ]
# 148: },
# 149: {
# 150: "number": 22,
# 151: "title": "Pet care",
# 152: "description": [
# 153: "Payton and Harlow have a pet and share responsibilities to ensure its well-being—Payton focusing on feeding and health, while Harlow manages exercise and engagement. Payton prepares nutritious meals, tracks the pet’s diet, and schedules regular vet visits to monitor overall health. Harlow takes the pet for daily walks, engages in interactive playtime, and reinforces positive training routines for consistency. They communicate regularly, discuss behavioral changes or concerns, and adjust their care routine as needed to provide the best possible life for their pet."
# 154: ]
# 155: },
# 156: {
# 157: "number": 23,
# 158: "title": "Leading a community clean up",
# 159: "description": [
# 160: "Avery and Marley lead a community cleanup, each playing a vital role in its success—with Avery focusing on volunteer coordination and Marley handling logistics. Avery recruits helpers, spreads awareness through promotions, and tracks progress to keep participants engaged. Marley gathers necessary supplies, arranges waste disposal, and assigns tasks to ensure efficiency. While Avery fosters community involvement, Marley ensures operations run smoothly. After each event, they review outcomes, discuss improvements, and plan future initiatives mutually to maximize their impact."
# 161: ]
# 162: },
# 163: {
# 164: "number": 24,
# 165: "title": "Retail store management",
# 166: "description": [
# 167: "Briar and Harper work in a store, each focusing on key aspects—Briar handling operations and Harper handling customer service. Briar monitors inventory levels, sets competitive pricing, and ensures transactions are efficient and accurate. Harper interacts with customers, provides assistance, resolves complaints, and enhances the overall shopping experience. While Briar keeps the backend organized, Harper ensures the storefront remains welcoming and engaging. They regularly analyse sales trends together, adjusting strategies to improve efficiency, customer satisfaction, and overall performance."
# 168: ]
# 169: },
# 170: {
# 171: "number": 25,
# 172: "title": "Moving to a new place",
# 173: "description": [
# 174: "Harper and Wren are moving to a new place, each taking on specific responsibilities—Harper organizing packing and Wren managing transportation. Harper categorizes items, sorts through belongings to donate unused things, and secures boxes to ensure everything is neatly packed. Wren rents a truck, coordinates timing to ensure a smooth move, and carefully handles items to prevent damage. Once the move is complete, they unpack together, setting up their new home efficiently and ensuring everything has its place. They also clean the space, organize utilities, and finalize any outstanding tasks."
# 175: ]
# 176: },
# 177: {
# 178: "number": 26,
# 179: "title": "Language Learning partners",
# 180: "description": [
# 181: "Avery and Payton are learning a new language, each using a different approach—Avery focusing on speaking and Payton on writing. Avery practices conversations, listens to native speakers, and memorizes useful phrases to improve fluency. Payton studies grammar rules, completes writing exercises, and expands their vocabulary for better sentence structure. They support each other’s progress by testing one another weekly, combining their strengths to develop well-rounded language skills. Their collaboration keeps them motivated and helps them learn more effectively, track milestones, and refine their pronunciation."
# 182: ]
# 183: },
# 184: {
# 185: "number": 27,
# 186: "title": "eSport partnership",
# 187: "description": [
# 188: "Laramie and Briar compete in eSports, each playing a crucial role in their team’s success—Laramie focusing on strategy and Briar on practice management. Laramie studies opponents, refines game plans, and leads tactical discussions to improve gameplay. Briar organizes practice schedules, reviews performance metrics, and keeps team morale high to maintain focus and motivation. While Laramie ensures smart in-game decisions, Briar optimizes preparation and teamwork. They analyze match results together, adjusting tactics to stay competitive and make sure they are improving."
# 189: ]
# 190: },
# 191: {
# 192: "number": 28,
# 193: "title": "Speech preparation",
# 194: "description": [
# 195: "Harlow and Sage are preparing a speech for their project, each contributing to a different aspect—Harlow focusing on delivery and Sage on content structure. Harlow practices tone, refines body language, and improves voice projection to enhance audience engagement. Sage organizes key points, ensures clarity, and adjusts timing for a smooth, effective flow. While Harlow brings confidence and presence to the speech, Sage fine-tunes the message for maximum impact. They rehearse together, providing constructive feedback and making necessary adjustments until they feel fully prepared and polished."
# 196: ]
# 197: },
# 198: {
# 199: "number": 29,
# 200: "title": "Home office set up",
# 201: "description": [
# 202: "Avery and Harlow are setting up a home office, each focusing on different aspects—Avery designing the space and Harlow managing technology. Avery arranges furniture, optimizes lighting, and decorates to create a comfortable and inspiring workspace. Harlow sets up computers, installs essential software, configures networks, and ensures internet reliability for seamless connectivity. While Avery enhances organization and aesthetics, Harlow focuses on functionality, technical efficiency, and system integration. They collaborate to adjust the layout as needed, ensuring the space is both productive and visually appealing."
# 203: ]
# 204: },
# 205: {
# 206: "number": 30,
# 207: "title": "Co-writing a book",
# 208: "description": [
# 209: "Marley and Indigo are writing a book, each contributing their strengths—Marley focusing on story development and Indigo on editing. Marley drafts chapters, develops characters, structures the plot, and outlines key events to create a compelling narrative. Indigo refines grammar, ensures consistency, polishes the language, checks for errors, and improves sentence structure to enhance clarity and flow. While Marley brings creativity and storytelling, Indigo provides precision and refinement. They collaborate in reviewing each draft, making revisions, and perfecting details until they are fully satisfied with the final manuscript."
# 210: ]
# 211: },
# 212: {
# 213: "number": 31,
# 214: "title": "Shelter co-workers",
# 215: "description": [
# 216: "Marley and Laramie help at a shelter, each focusing on different responsibilities—Marley organizing resources and Laramie working directly with residents. Marley sorts donations, manages supplies, and coordinates volunteer efforts to ensure operations run smoothly. Laramie distributes meals, listens to residents’ concerns, and assists with paperwork to provide necessary support. While Marley maintains structure and organization, Laramie offers hands-on assistance and emotional support. After each shift, they debrief together, discussing challenges, sharing insights, and finding ways to improve their work."
# 217: ]
# 218: },
# 219: {
# 220: "number": 32,
# 221: "title": "car ownership",
# 222: "description": [
# 223: "Payton and Harlow take care of their car, each focusing on different aspects—Payton handling inspections and Harlow managing cleanliness. Payton checks oil levels, monitors tire pressure, schedules regular servicing, and tracks repairs to ensure the car runs smoothly. Harlow takes care of cleaning the interior, washing the exterior, organizing the trunk, and vacuuming the seats to keep everything tidy. They work together to maintain maintenance records, ensuring their car remains in top condition and stays reliable for every journey."
# 224: ]
# 225: },
# 226: {
# 227: "number": 33,
# 228: "title": "Planning a hiking trip",
# 229: "description": [
# 230: "Laramie and Indigo plan a hiking trip, each taking charge of different tasks—Laramie researching trails and Indigo organizing gear. Laramie checks trail difficulty, reviews weather forecasts, ensures all safety guidelines are followed, and identifies potential hazards for a secure experience. Indigo packs essential equipment, arranges food, makes sure first-aid supplies are ready, and coordinates with local guides in case of emergencies. They communicate about potential risks, review emergency plans, and ensure everything is prepared for a safe and enjoyable adventure in the great outdoors."
# 231: ]
# 232: },
# 233: {
# 234: "number": 34,
# 235: "title": "science project partnership",
# 236: "description": [
# 237: "Avery and Harlow are working on a science project, each focusing on key tasks—Avery conducting experiments and Harlow documenting the entire process. Avery sets up tests, adjusts variables, records results, analyzes data, and monitors outcomes to gather valuable insights. Harlow writes detailed reports, prepares visuals like charts or graphs, structures the final presentation, and organizes findings to ensure clear communication. They collaborate by practicing their explanation together, refining how they present the project to ensure it’s informative, engaging, and accurate for their audience."
# 238: ]
# 239: },
# 240: {
# 241: "number": 35,
# 242: "title": "Redecorating an apartment",
# 243: "description": [
# 244: "Harper and Marley are redecorating their apartment, each taking responsibility for different areas—Harper focusing on choosing furniture and Marley managing the layout. Harper selects colors, buys decorations, matches themes, researches trends, and shops for accessories to create a unified aesthetic throughout the space. Marley arranges the furniture, maximizes available space, ensures the layout is both functional and comfortable, and coordinates with contractors for any renovations. Together, they finalize decisions based on comfort and style, making sure every element complements each other, so that the space is both beautiful and practical for everyday living."
# 245: ]
# 246: },
# 247: {
# 248: "number": 36,
# 249: "title": "Hosting a game night",
# 250: "description": [
# 251: "Marley and Wren host a game night, each preparing different aspects—Marley setting up games and Wren handling food and drinks. Marley explains the rules, organizes teams, ensures fairness during gameplay, monitors time, and adjusts difficulty levels to create an enjoyable and competitive atmosphere. Wren prepares snacks, manages drinks, sets the right ambiance with music and lighting, and coordinates with guests for dietary preferences . Throughout the night, they keep track of everyone’s enjoyment, making adjustments as needed to ensure a memorable experience for all guests."
# 252: ]
# 253: },
# 254: {
# 255: "number": 37,
# 256: "title": "Art show partnership",
# 257: "description": [
# 258: "Laramie and Avery organize an art show, each overseeing different aspects—Laramie managing logistics and Avery curating the displays. Laramie handles the venue booking, schedules artists, promotes the event to attract visitors, and coordinates transportation for artwork. Avery arranges the artwork, sets the themes for each section, and ensures the proper lighting to highlight the pieces. They collaborate in reviewing the final setup together to ensure everything aligns perfectly. Their combined efforts create a visually stunning and well-organized art show that engages attendees and showcases the artists' work beautifully."
# 259: ]
# 260: },
# 261: {
# 262: "number": 38,
# 263: "title": "Hosting a podcast",
# 264: "description": [
# 265: "Avery and Indigo host a podcast, each contributing differently—Avery managing topics and Indigo handling editing. Avery researches potential guests, prepares scripts, leads discussions, organizes interview schedules, and curates content. Indigo records the sessions, edits the audio for clarity and flow, uploads the episodes, monitors sound quality, and formats the content for different platforms. Together, they review feedback from their audience, discuss areas for improvement, adjust future content, and brainstorm new ideas. Their teamwork ensures a polished and engaging podcast experience for their listeners."
# 266: ]
# 267: },
# 268: {
# 269: "number": 39,
# 270: "title": "Running a food drive",
# 271: "description": [
# 272: "Briar and Harper run a food drive, each taking charge of different responsibilities—Briar gathering donations and Harper overseeing distribution. Briar contacts donors, sets up collection points, tracks contributions, manages inventory, and coordinates with businesses for support. Harper organizes the packing of food, coordinates volunteers, manages logistics for transportation, ensures timely delivery to those in need, and monitors the process for efficiency. After the drive, they evaluate its success based on the impact it had on the community, discuss areas for improvement, and plan future initiatives to help more people."
# 273: ]
# 274: },
# 275: {
# 276: "number": 40,
# 277: "title": "Brewing partnership",
# 278: "description": [
# 279: "Harlow and Avery are brewing homemade drinks, each with a specific role—Harlow focusing on flavors and Avery managing fermentation. Harlow experiments with ingredients, adjusts recipes to improve taste, tests each batch for balance, records results, and makes notes for future experiments. Avery tracks brewing times, ensures the process maintains cleanliness, sanitizes equipment, bottles the final product, and monitors storage conditions. Together, they refine their brewing methods based on the results of each batch, making adjustments to improve the quality and taste of their homemade drinks."
# 280: ]
# 281: },
# 282: {
# 283: "number": 41,
# 284: "title": "Organizing a charity event",
# 285: "description": [
# 286: "Harlow and Avery are organizing a charity event, each contributing in different ways—Harlow managing outreach and Avery coordinating logistics. Harlow contacts potential donors, spreads awareness through social media, promotes the fundraiser, and builds partnerships to encourage participation. Avery handles venue bookings, arranges event activities, tracks donations, and manages volunteer schedules to ensure everything runs smoothly. After the event, they evaluate its success together, discussing the impact of their efforts, analyzing feedback, and planning improvements for future events to further support the cause."
# 287: ]
# 288: },
# 289: {
# 290: "number": 42,
# 291: "title": "Bakery co-ownership",
# 292: "description": [
# 293: "Kendall and Harlow run a small bakery, each focusing on different areas to ensure success—Kendall handling sales and Harlow perfecting recipes. Kendall manages customer orders, oversees service, sets pricing, tracks inventory, and organizes promotions to maintain business. Harlow experiments with ingredients, bakes a variety of goods, ensures each item meets quality standards, and monitors baking times for consistency. They regularly review customer feedback together to refine their offerings, introducing new products and making adjustments to improve taste and presentation."
# 294: ]
# 295: },
# 296: {
# 297: "number": 43,
# 298: "title": "Dog training partnership",
# 299: "description": [
# 300: "Sage and Kendall train their dog, each taking responsibility for different aspects—Sage teaching tricks and Kendall reinforcing discipline. Sage introduces new commands, rewards progress, ensures consistency, and tracks the dog’s reactions during training. Kendall focuses on correcting bad habits, tracking improvements, and managing the training schedule to ensure steady progress. Together, they assess the results of their efforts, discussing what’s working well and making adjustments as needed. Their teamwork helps the dog learn effectively, promoting good behavior and a strong bond with its owners."
# 301: ]
# 302: },
# 303: {
# 304: "number": 44,
# 305: "title": "Project leadership",
# 306: "description": [
# 307: "Briar and Kendall lead a work project, each handling different areas—Briar managing deadlines and Kendall refining strategy. Briar assigns tasks to the team, sets clear milestones, and regularly checks progress to ensure everything stays on track. Kendall organizes brainstorming sessions, ensures team efficiency, and monitors workflow to optimize productivity. They collaborate closely throughout the project, regularly reviewing the work, making adjustments when needed, and combining their efforts to report findings together, ensuring the project is completed successfully and on time."
# 308: ]
# 309: },
# 310: {
# 311: "number": 45,
# 312: "title": "Backyard redesign",
# 313: "description": [
# 314: "Payton and Avery redesign their backyard, each taking on different tasks—Payton focusing on planning and Avery handling maintenance. Payton selects plants, designs layouts, coordinates purchases, and manages the budget to create a beautiful and functional space. Avery takes responsibility for digging, planting, regularly watering the garden, and maintaining soil health to ensure everything thrives. Together, they adjust designs based on the results, observing how plants grow and making changes to improve the overall aesthetic and health of the garden. Their collaboration brings the backyard vision to life."
# 315: ]
# 316: },
# 317: {
# 318: "number": 46,
# 319: "title": "food contest",
# 320: "description": [
# 321: "Payton and Harper enter a food contest, each contributing in different ways—Payton focusing on creativity and Harper managing execution. Payton selects unique recipes, experiments with different flavors, tests the presentation, and designs the overall concept to ensure it stands out. Harper handles timing, organizes ingredients, perfects cooking techniques, tracks progress, and ensures consistency in the dish’s preparation to achieve the best possible results. Together, they refine their dish before submission, making adjustments as needed to ensure their creation is both innovative and well-executed, ultimately enhancing their chances of success in the competition."
# 322: ]
# 323: },
# 324: {
# 325: "number": 47,
# 326: "title": "Conducting an experiment at home",
# 327: "description": [
# 328: "Harper and Marley conduct a home experiment, each playing an important role—Harper designing the procedures while Marley recording the results. Harper selects hypotheses, sets up tests, manages variables, monitors progress, adjusting the experiment’s direction based on observations. Marley logs the data, analyzes patterns, summarizes findings, ensuring consistency in the data collection process. Together, they regularly assess the experiment’s progress, adjusting their approach based on outcomes. Their collaboration ensures that the experiment is carried out thoroughly, with precise data collection and analysis to yield meaningful results."
# 329: ]
# 330: },
# 331: {
# 332: "number": 48,
# 333: "title": "Thrift adventure",
# 334: "description": [
# 335: "Avery and Harlow are going thrifting, each focusing on different aspects—Avery searching for fashion items and Harlow looking for home décor. Avery looks for vintage clothing, checks the quality, styles outfits, and selects pieces that align with current trends. Harlow finds home décor, tests functionality, compares prices, and organizes items to ensure they’re getting the best deals. After browsing, they come together to make final choices, sharing thoughts on what works best for their needs. Their collaboration ensures they find the perfect pieces for both fashion and home."
# 336: ]
# 337: },
# 338: {
# 339: "number": 49,
# 340: "title": "board game design",
# 341: "description": [
# 342: "Kendall and Wren are designing a board game, each taking on distinct responsibilities—Kendall creating the mechanics and Wren refining the aesthetics. Kendall develops the rulebook, constructs prototypes, evaluates player interactions, modifies game flow for engagement, and balances difficulty levels to ensure fairness. Wren focuses on designing artwork, selecting components, coordinating production, finalizing packaging, and formatting the board for a visually appealing experience. They collaborate regularly to test the game with friends to gather feedback, making final adjustments before releasing it to the public and ensuring it is both enjoyable and well-designed."
# 343: ]
# 344: },
# 345: {
# 346: "number": 50,
# 347: "title": "Furniture Building",
# 348: "description": [
# 349: "Wren and Briar build furniture; each try to contribute to different parts of the process—Wren focusing on design and Briar on assembly. Wren drafts blueprints, calculates measurements, sources materials, tests structural integrity, and refines aesthetic details to ensure the design is functional and stylish. Briar cuts the wood, fastens components, reinforces joints, smooths surfaces, and ensures everything is stable and secure. After assembly, they check the durability of the finished product collaboratively and make sure it is built to last. Together, they complete each piece with attention to detail and quality craftsmanship."
# 350: ]
# 351: },
# 352: {
# 353: "number": 51,
# 354: "title": "Social media partnership",
# 355: "description": [
# 356: "\" Payton and Briar run a social media page, each handling distinct tasks—Payton creating content, Briar tracking engagement. Payton writes creative captions, edits videos for clarity, schedules posts to maximize reach. Briar analyzes metrics, monitors reach, interacts with followers, refines strategy based on data insights. They frequently review analytics together, adjusting approach to improve visibility, maintain audience interest. Their teamwork ensures a dynamic presence that adapts to evolving trends with unwavering, consistent determination.\""
# 357: ]
# 358: },
# 359: {
# 360: "number": 52,
# 361: "title": "Organizing a local festival",
# 362: "description": [
# 363: "Briar and Harlow organize a local festival, each taking charge in different ways—Briar handling logistics, Harlow promoting the event. Briar secures vendors, arranges permits, manages schedules to ensure everything runs smoothly, coordinating with various teams. Meanwhile, Harlow advertises the festival, engages with media outlets, attracts visitors through targeted campaigns and community outreach. After the event, they measure success by reviewing attendance, feedback, overall impact, using results to plan future improvements. They also evaluate key partnerships, sponsorship growth."
# 364: ]
# 365: },
# 366: {
# 367: "number": 53,
# 368: "title": "Running a photography business",
# 369: "description": [
# 370: "Wren and Harper run a photography business, each playing a key role—Wren handling shoots and Harper managing the editing process. Wren directs clients, sets up lighting scenes, and takes high-quality photos to capture the perfect moments. Harper retouches images, selects the final shots that best represent the session, and prepares albums that showcase their work. They organize bookings, review customer feedback together to identify areas of improvement, and finalize contracts, ensuring each project leaves clients satisfied and eager to come back for more memorable photoshoots."
# 371: ]
# 372: },
# 373: {
# 374: "number": 54,
# 375: "title": "Book collection project",
# 376: "description": [
# 377: "Payton and Indigo arrange their book collection, each taking charge of distinct tasks—Payton categorizing and Indigo designing the layout. Payton carefully sorts books by genre, labels sections clearly, and creates a comprehensive catalog to organize the collection. Meanwhile, Indigo arranges shelves thoughtfully, decorates the space to enhance visual appeal, and ensures accessibility for all readers. Together, they review the system, discussing improvements and making adjustments to optimize organization. Their collaborative efforts result in a functional and aesthetically pleasing book collection for future enjoyment."
# 378: ]
# 379: },
# 380: {
# 381: "number": 55,
# 382: "title": "stand up comedy collaboration",
# 383: "description": [
# 384: "Laramie and Sage try stand-up comedy, each playing a distinct role—Laramie writing jokes and Sage refining delivery. Laramie brainstorms themes, tests material, and carefully structures sets to engage the audience. Sage practices timing, adjusts tone, and interacts with the crowd during performances to capture reactions. They review recordings together, analyze responses, and refine scripts, discussing what works best and making adjustments based on audience feedback. Their collaboration enables them to continuously improve, ensuring each performance is dynamic, engaging, and thoroughly entertaining for all who attend with great success."
# 385: ]
# 386: },
# 387: {
# 388: "number": 56,
# 389: "title": "Blog partnership",
# 390: "description": [
# 391: "Indigo and Briar run a blog, each contributing unique skills—Indigo focusing on writing articles while Briar manages visuals. Indigo researches engaging topics, drafts posts, and ensures readability. Meanwhile, Briar takes original photos, designs layouts, and enhances presentation to capture readers' attention. Together, they revise every piece before posting, ensuring quality content and visual harmony. Their teamwork creates a dynamic blog that informs, entertains, and continuously evolves to meet audience needs. Their passion, creativity, and dedication drive success."
# 392: ]
# 393: },
# 394: {
# 395: "number": 57,
# 396: "title": "Educational course creation",
# 397: "description": [
# 398: "Avery and Sage are creating an educational course; they share duties to blend content creation with lesson structuring. Avery writes materials, records engaging videos, and practical examples to illustrate key concepts. Sage organizes course modules, builds quizzes, and ensures lessons remain engaging and accessible for students. Together, they regularly review and refine the curriculum based on student feedback, enhancing content quality and instructional design to maximize learning outcomes and foster a dynamic, effective educational experience."
# 399: ]
# 400: },
# 401: {
# 402: "number": 58,
# 403: "title": "Scape room challenge",
# 404: "description": [
# 405: "Payton and Indigo attempt an escape room challenge, each approaching with a distinct strategy. Payton focuses on solving puzzles by deciphering intricate clues, testing creative ideas, and connecting patterns hidden throughout the room. Meanwhile, Indigo manages time efficiently by tracking progress, staying organized, and setting clear priorities to ensure they do not fall behind. Together, they communicate constantly, adjusting their tactics and pooling their strengths to escape before time runs out. Their excellent teamwork proves essential for overcoming every obstacle successfully."
# 406: ]
# 407: },
# 408: {
# 409: "number": 59,
# 410: "title": "Organizing a charity concert",
# 411: "description": [
# 412: "Laramie and Payton are organizing a charity concert, each contributing their expertise to ensure a successful event. Laramie manages the artistic side by scouting talented performers, scheduling rehearsals, and coordinating seamless on-stage execution. Payton handles logistics by securing the perfect venue, arranging sound and lighting, and overseeing ticket sales and donations. Together, they diligently track progress and adjust plans based on valuable audience feedback, working collaboratively to create an engaging event that raises crucial funds for a worthy cause and strengthens community spirit."
# 413: ]
# 414: },
# 415: {
# 416: "number": 60,
# 417: "title": "Urban gardening project",
# 418: "description": [
# 419: "Marley and Avery are starting an urban garden, each contributing to distinct skills to ensure a thriving green space. Marley takes charge of planting, selecting crops, preparing the soil, and watering to foster healthy growth. Meanwhile, Avery handles logistics by finding an ideal space, securing permits, and organizing supplies to support the garden's needs. Together, they monitor progress and evaluate harvest results, discussing improvements and celebrating successes along the way. Their teamwork transforms a simple plot into a vibrant urban oasis."
# 420: ]
# 421: },
# 422: {
# 423: "number": 61,
# 424: "title": "Documenting travels",
# 425: "description": [
# 426: "Avery and Indigo document their travels, each bringing a unique perspective to their shared adventures. Avery focuses on writing, journaling experiences in detail, researching destinations for deeper context, and crafting engaging stories to share insights. Indigo captures the visual essence of their journey by taking photographs, editing footage, and curating stunning albums that complement Avery’s narratives. Together, they publish their stories, blending words and imagery to create immersive travel content that inspires others and preserves their memories in a meaningful way."
# 427: ]
# 428: },
# 429: {
# 430: "number": 62,
# 431: "title": "Music co-production",
# 432: "description": [
# 433: "Harlow and Payton produce songs, each contributing their unique expertise to create music. Harlow focuses on writing melodies, playing instruments, and structuring tracks to establish the foundation. Meanwhile, Payton handles mixing, adjusting sound levels, editing recordings, and enhancing overall audio quality for a professional finish. Together, they refine each piece, ensuring a balanced blend of creativity and technical precision. Before release, they review every detail, making final adjustments to their sound and deliver an engaging, memorable listening experience."
# 434: ]
# 435: },
# 436: {
# 437: "number": 63,
# 438: "title": "Camping adventure",
# 439: "description": [
# 440: "Laramie and Indigo go camping, each taking on essential responsibilities to ensure a smooth outdoor experience. Laramie focuses on shelter, gathering firewood, setting up tents, and ensuring their campsite is safe and secure. Meanwhile, Indigo manages food, cooking meals, storing supplies properly, and keeping a close eye on local wildlife. Together, they check weather conditions before each trip, planning routes, and adjust their setup based on the environment. Their teamwork and communication allow them to enjoy nature while staying prepared and comfortable.."
# 441: ]
# 442: },
# 443: {
# 444: "number": 64,
# 445: "title": "Stage production",
# 446: "description": [
# 447: "Kendall and Avery direct a play, working to bring their vision to life. Kendall focuses on performances, coaching actors, refining dialogue delivery, and ensuring emotional depth. Avery oversees production, designing staging, coordinating costumes, and managing lighting. They collaborate on script development, organize rehearsals, and adjust scenes for maximum impact. Together, they ensure seamless transitions, guide the cast and crew, and fine-tune every detail. Their combined efforts create a polished, engaging production that captivates audiences and brings the story to life."
# 448: ]
# 449: },
# 450: {
# 451: "number": 65,
# 452: "title": "Jewellery creation",
# 453: "description": [
# 454: "Briar and Harlow create handmade jewellery, each focusing on key aspects of the process. Briar designs the pieces, sketching ideas, selecting high-quality materials, and refining concepts to ensure a unique style. Harlow handles the assembly, carefully crafting each piece, ensuring its durability, and polishing the final product to perfection. Together, they coordinate the pricing of their jewellery, oversee the preparation for sale, and manage customer relations, while refining their marketing strategies. Their combined skills and dedication result in beautiful, high-quality pieces that reflect both creativity and craftsmanship."
# 455: ]
# 456: },
# 457: {
# 458: "number": 66,
# 459: "title": "Furniture revamp",
# 460: "description": [
# 461: "Briar and Harlow restore old furniture, each focusing on a specific role to bring pieces back to life. Briar strips paint, sands wood, removes stains, and repairs any damage to prepare the surface for refinishing. Harlow then applies coatings, polishes finishes, and ensures the longevity of each piece through careful preservation and protective treatments. Together, they check the final results, ensuring the furniture is in excellent condition before selling or displaying. Their combined efforts transform worn-out items into beautifully restored, functional, and high-quality works of art."
# 462: ]
# 463: },
# 464: {
# 465: "number": 67,
# 466: "title": "Comic creation",
# 467: "description": [
# ...
# 546: ]
# 547: },
# 548: {
# 549: "number": 79,
# 550: "title": "Designing a mini-golf course",
# 551: "description": [
# 552: "Harper and Harlow are designing a mini-golf course. Both contribute to different aspects—Harper creating obstacles and Harlow managing logistics. Harper designs challenging holes, tests layouts, and adds creative themes. Harlow arranges course setup, coordinates schedules, handles marketing, and manages budgeting. Harper ensures the obstacles are fun and engaging, while Harlow makes sure the experience runs smoothly for players. They review feedback from visitors to refine and improve the course, making adjustments to both the design and logistics to ensure a memorable and well-organized experience for all."
# 553: ]
# 554: },
# 555: {
# 556: "number": 80,
# 557: "title": "Maintaining an urban beehive",
# 558: "description": [
# 559: "Kendall and Laramie maintain an urban beehive. Both have duties—Kendall monitoring the hive and Laramie harvesting honey. Kendall inspects colony health, checks for pests, manages hive expansion, and tracks bee activity. Laramie extracts honey, filters wax, and packages products for sale. Kendall ensures the bees have a sustainable environment, while Laramie maintains equipment and storage. They collaborate on seasonal management, adjusting care based on weather, nectar flow, and hive conditions. Together, they educate the community on pollination, environmental responsibility, and the importance of urban beekeeping."
# 560: ]
# 561: },
# 562: {
# 563: "number": 81,
# 564: "title": "Organizing a coastal cleanup",
# 565: "description": [
# 566: "Kendall and Harlow organize a coastal cleanup. Both take roles—Kendall coordinating volunteers and Harlow handling logistics. Kendall promotes the event, gathers sponsors, and tracks participation numbers. Harlow distributes cleanup tools, sorts collected waste, and ensures proper recycling and disposal. Kendall communicates with local organizations to gain support, while Harlow arranges transportation for debris removal. They document progress, analyze collected data, and report results to the community. Together, they work to raise awareness and enhance environmental conservation efforts along the coastline."
# 567: ]
# 568: },
# 569: {
# 570: "number": 82,
# 571: "title": "Home business",
# 572: "description": [
# 573: "Sage and Payton create organic soaps. Both share tasks—Sage experimenting with formulas and Payton handling packaging. Sage selects natural ingredients, tests scent combinations, and refines recipes for quality. Payton designs labels, wraps bars, and creates appealing product displays. Sage researches skin benefits and ensures sustainability, while Payton manages branding and promotions. They collaborate on pricing, production efficiency, and expanding their product line. Together, they track customer feedback and adjust formulas or designs to meet consumer preferences and market demand."
# 574: ]
# 575: },
# 576: {
# 577: "number": 83,
# 578: "title": "Organizing a film festival",
# 579: "description": [
# 580: "Sage and Marley are organizing a film festival. Both contribute—Sage curating films and Marley managing event logistics. Sage selects movies, researches directors, and arranges Q&A sessions. Marley secures venues, coordinates screening schedules, and oversees ticket sales. Sage ensures a diverse lineup, balancing genres and themes, while Marley handles permits, seating, and technical setups. They collaborate on marketing, reaching out to press and engaging audiences effectively. After the event, they gather feedback, analyze attendance, and discuss potential improvements for future festivals."
# 581: ]
# 582: },
# 583: {
# 584: "number": 84,
# 585: "title": "Fixing old electronics",
# 586: "description": [
# 587: "Harper and Avery fix old electronics. Both take charge—Harper diagnosing issues and Avery handling repairs. Harper researches common problems, tests circuits, and sources replacement parts. Avery disassembles devices, replaces faulty components, and reassembles gadgets. Harper ensures compatibility, troubleshoots errors, and fine-tunes performance. Avery cleans connections, checks wiring, and optimizes durability. They document fixes, share solutions, and improve efficiency over time. Before finalizing, they conduct thorough functionality tests to confirm proper operation and ensure reliability for long-term use."
# 588: ]
# 589: },
# 590: {
# 591: "number": 85,
# 592: "title": "Fashion brand co-ownership",
# 593: "description": [
# 594: "Indigo and Kendall are launching an eco-friendly fashion brand. Both have roles—Indigo designing apparel and Kendall sourcing materials. Indigo sketches outfits, chooses fabrics, and ensures comfort and style. Kendall researches sustainable materials, negotiates with ethical suppliers, and oversees production costs. Indigo focuses on innovative designs, keeping environmental impact in mind. Kendall ensures the brand’s supply chain supports fair trade practices and minimal waste. They collaborate to create a brand that champions responsible consumption, promoting eco-conscious choices in the fashion industry."
# 595: ]
# 596: },
# 597: {
# 598: "number": 86,
# 599: "title": "Running a bookstore",
# 600: "description": [
# 601: "Indigo and Wren run a bookstore. Both divide tasks—Indigo handling inventory and Wren engaging with customers. Indigo orders books, tracks stock, manages suppliers, and ensures the bookstore is always stocked. Wren arranges displays, hosts events like author readings, and offers personalized book recommendations to customers. Indigo monitors trends and adapts inventory accordingly. Wren builds strong customer relationships, creating a welcoming atmosphere. Together, they ensure to stay current with literary trends and deliver a great customer experience."
# 602: ]
# 603: },
# 604: {
# 605: "number": 87,
# 606: "title": "Animal rescue",
# 607: "description": [
# 608: "Wren and Sage help at an animal rescue. Both contribute—Wren assisting with adoptions and Sage caring for animals. Wren processes adoption applications, conducts interviews with potential adopters, and handles the necessary paperwork. Sage is responsible for feeding, grooming, and socializing the animals, ensuring they are well cared for and healthy. Together, they create a seamless adoption process, managing records, matching pets with loving homes. They work closely to ensure the animals’ needs are met while providing adopters with the support, education, and guidance they need throughout the process."
# 609: ]
# 610: },
# 611: {
# 612: "number": 88,
# 613: "title": "Hosting a cooking class",
# 614: "description": [
# 615: "Sage and Briar host a cooking class. Both take charge based on their experties—Sage planning recipes and Briar managing the class. Sage selects dishes, researches techniques, and prepares demonstrations. Briar organizes the class schedule, sets up equipment, and ensures participants stay on track. Sage provides guidance, answers questions, and helps with cooking tips. Briar assists with hands-on tasks, keeps the environment organized, and makes sure everyone is comfortable. Afterward, they gather feedback and adjust the class for a better learning experience."
# 616: ]
# 617: },
# 618: {
# 619: "number": 89,
# 620: "title": "Home renovation",
# 621: "description": [
# 622: "Sage and Laramie are renovating their home. Both take tasks—Sage handling demolition and Laramie focusing on rebuilding. Sage tears down old structures, removes debris, and preps surfaces for upgrades. Laramie installs new fixtures, paints walls, and lays flooring. Sage ensures proper disposal of materials, checks for structural stability, and clears space for renovations. Laramie measures dimensions, selects finishes, and refines details. They collaborate on design choices, balance aesthetics with function, and make adjustments as needed to complete their renovation successfully."
# 623: ]
# 624: },
# 625: {
# 626: "number": 90,
# 627: "title": "Organizimg a local play",
# 628: "description": [
# 629: "Harper and Wren put on a local play. Both contribute—Harper designing costumes and Wren managing lighting. Harper researches period styles, selects fabrics, and tailors outfits to fit the cast. Wren programs lighting cues, adjusts intensity, and creates mood-enhancing effects. Harper ensures each costume aligns with the character’s role, adds finishing touches, and oversees quick changes. Wren coordinates with the director, troubleshoots technical issues, and fine-tunes transitions. They work closely with the cast to ensure a seamless and visually stunning performance."
# 630: ]
# 631: },
# 632: {
# 633: "number": 91,
# 634: "title": "Co-assisting a hospital ward",
# 635: "description": [
# 636: "Harlow and Avery assist in a busy hospital ward. Both take roles—Harlow managing patient care and Avery handling medical records. Harlow checks vital signs, administers medications, and communicates with doctors. Avery updates charts, processes test results, and ensures documentation. Harlow monitors patient progress, responds to emergencies, and provides comfort. Avery schedules procedures, coordinates with departments, and maintains compliance with protocols. They collaborate to ensure smooth operations, efficient treatment, and high-quality patient care, working together to improve health outcomes."
# 637: ]
# 638: },
# 639: {
# 640: "number": 92,
# 641: "title": "Developing a mobile application",
# 642: "description": [
# 643: "Sage and Laramie are developing a new mobile application. Both share responsibilities—Sage handling the user interface and Laramie managing the backend. Sage designs the layout, creates wireframes, and tests interactions, ensuring the app’s functionality is intuitive. Laramie writes code, troubleshoots issues, ensures data security, and optimizes performance. They collaborate to integrate new features, refine design, and streamline the user experience. Sage leads usability tests, while Laramie implements updates. Together, they monitor feedback and continuously make improvements to create a seamless, user-friendly application."
# 644: ]
# 645: },
# 646: {
# 647: "number": 93,
# 648: "title": "Co-Teaching a Class",
# 649: "description": [
# 650: "Briar and Harlow are co-teaching a class. Both take on distinct roles—Briar leading discussions and Harlow managing activities. Briar explains concepts, facilitates group conversations, and answers questions. Harlow prepares materials, organizes hands-on exercises, and ensures student engagement. They collaborate on lesson plans, adjust pacing based on student needs, and offer support individually. Briar monitors student progress during lectures, while Harlow provides feedback during assignments. Together, they create an inclusive learning environment and assess students’ understanding, ensuring effective teaching outcomes."
# 651: ]
# 652: },
# 653: {
# 654: "number": 94,
# 655: "title": "Co-writing a research paper",
# 656: "description": [
# 657: "Sage and Wren work on a research paper. Both focus on different tasks—Sage gathering research and Wren writing the content. Sage searches academic journals, collects data, and synthesizes findings. Wren drafts the introduction, writes analysis sections, and ensures the paper’s clarity. They collaborate on outlining key points, revising drafts, and refining the methodology. Sage double-checks the references, while Wren ensures proper formatting and consistency. Together, they review the paper, revise the conclusions, and finalize it for submission, ensuring accuracy, quality, and coherence."
# 658: ]
# 659: },
# 660: {
# 661: "number": 95,
# 662: "title": "Medical laboratory collaboration",
# 663: "description": [
# 664: "Kendall and Avery work together in a medical laboratory to conduct tests. Both have distinct roles—Kendall handling sample collection and Avery analyzing results. Kendall prepares specimens, labels samples, and ensures proper handling. Avery runs diagnostic tests, interprets data, and records findings. They collaborate to maintain lab equipment, verify accuracy, and troubleshoot any issues. Kendall monitors quality control procedures, while Avery compiles reports and ensures compliance with health standards. Together, they work to provide accurate and timely results for patient care."
# 665: ]
# 666: },
# 667: {
# 668: "number": 96,
# 669: "title": "Childcare",
# 670: "description": [
# 671: "Laramie and Briar share childcare duties at home. Both take on different roles—Laramie managing daily routines and Briar handling activities. Laramie prepares meals, ensures nap times, and oversees homework. Briar plans playdates, organizes educational games, and reads books. They communicate about children's needs, monitor progress, and ensure safety. Laramie tracks health appointments and schedules, while Briar addresses emotional and social well-being. Together, they create a balanced environment by maintaining structure and providing fun, fostering a nurturing atmosphere for their children's development."
# 672: ]
# 673: },
# 674: {
# 675: "number": 97,
# 676: "title": "Running  a farm",
# 677: "description": [
# 678: "Sage and Avery are running a small farm together. Both take on different responsibilities—Sage managing crops and Avery tending to animals. Sage plants seeds, monitors growth, and harvests produce. Avery feeds livestock, collects eggs, and ensures animal health. They work together to maintain equipment, repair fences, and plan seasonal tasks. Sage tracks inventory and markets produce, while Avery focuses on breeding and caring for the animals. Together, they create a self-sustaining farm by balancing crop production with animal husbandry."
# 679: ]
# 680: },
# 681: {
# 682: "number": 98,
# 683: "title": "Leading a book club",
# 684: "description": [
# 685: "Avery and Payton lead a vibrant book club, with each taking on key responsibilities. Avery is in charge of selecting books, researching titles, and organizing the reading schedule to ensure variety. While Avery provides detailed summaries to enhance understanding, Payton facilitates discussions by encouraging participation, moderating talks, and tracking key themes throughout the books. Together, they collaborate to adapt to the interests and preferences of club members, adjusting their approach to keep discussions lively, inclusive, and relevant to everyone’s reading experiences."
# 686: ]
# 687: },
# 688: {
# 689: "number": 99,
# 690: "title": "Leading a construction project",
# 691: "description": [
# 692: "Kendall and Avery lead a construction project. Both take charge—Kendall overseeing the design and Avery managing construction. Kendall works with architects, finalizes blueprints, and ensures the design aligns with community needs. Avery coordinates labor, supervises contractors, and monitors the construction process. Kendall handles permits, safety regulations, and budget allocation, while Avery ensures deadlines are met, materials are ordered, and quality is maintained. Together, they oversee the project’s completion, making adjustments as needed to stay on track and within budget."
# 693: ]
# 694: },
# 695: {
# 696: "number": 100,
# 697: "title": "Managing a local delivery system",
# 698: "description": [
# 699: "Payton and Avery are managing a local delivery system. Both have key roles—Payton handling logistics and Avery overseeing drivers. Payton plans routes, tracks orders, and ensures timely deliveries. Avery recruits drivers, organizes schedules, and manages customer communication. Payton monitors inventory, adjusts delivery zones, and coordinates with suppliers. Avery ensures proper documentation, resolves issues, and maintains driver performance. Together, they analyze customer feedback, refine processes, and optimize delivery efficiency, to improve service and reduce delivery times."
# 700: ]
# 701: }
# 702: ]

# %%
import json
import re
from collections import Counter

# Load the scenarios
with open("RandomNeutralScenarios_Rebalanced.json", "r", encoding="utf-8") as f:
    scenarios = json.load(f)

# List of unique names
names = {
    "Laramie", "Sage", "Harlow", "Avery", "Kendall", "Marley",
    "Briar", "Harper", "Wren", "Payton", "Indigo"
}

# Prepare counters
scenario_level_counts = Counter()
raw_frequency_counts = Counter()

# Regex pattern to find names in text
name_pattern = r'\b(' + '|'.join(names) + r')\b'

for scenario in scenarios:
    text = scenario["description"][0]

    # Raw frequency count (count ALL appearances of names)
    matches = re.findall(name_pattern, text)
    raw_frequency_counts.update(matches)

    # Scenario-level: count only the first 2 distinct names per scenario
    words = text.split()
    seen_names = []
    for word in words:
        cleaned = word.strip(",.?!")
        if cleaned in names and cleaned not in seen_names:
            seen_names.append(cleaned)
        if len(seen_names) == 2:
            break
    for name in seen_names:
        scenario_level_counts[name] += 1

# Print side-by-side comparison
print(f"{'Name':<10} {'Scenarios':>10} {'Total Mentions':>20}")
print("-" * 42)
for name in sorted(names):
    print(f"{name:<10} {scenario_level_counts[name]:>10} {raw_frequency_counts[name]:>20}")
# Out:
# Name        Scenarios       Total Mentions
# ------------------------------------------
# Avery              19                   60
# Briar              18                   52
# Harlow             19                   59
# Harper             17                   55
# Indigo             18                   51
# Kendall            18                   52
# Laramie            18                   56
# Marley             18                   53
# Payton             19                   56
# Sage               18                   53
# Wren               18                   54

# %%
import json
from collections import Counter, defaultdict

# Load scenarios
with open("RandomNeutralScenarios_Rebalanced.json", "r", encoding="utf-8") as f:
    scenarios = json.load(f)

names = {
    "Laramie", "Sage", "Harlow", "Avery", "Kendall", "Marley",
    "Briar", "Harper", "Wren", "Payton", "Indigo"
}

# Track:
# - How often each name appears in position 1 or 2
# - Pair frequencies
position_counts = {"name1": Counter(), "name2": Counter()}
pair_counts = Counter()

for scenario in scenarios:
    text = scenario["description"][0]
    words = text.split()
    seen_names = []
    for word in words:
        cleaned = word.strip(",.?!")
        if cleaned in names and cleaned not in seen_names:
            seen_names.append(cleaned)
        if len(seen_names) == 2:
            break
    if len(seen_names) == 2:
        name1, name2 = seen_names
        position_counts["name1"][name1] += 1
        position_counts["name2"][name2] += 1
        pair = tuple(sorted([name1, name2]))
        pair_counts[pair] += 1

# Print position consistency
print("\n📌 Name Position Consistency:")
print(f"{'Name':<10} {'As Name 1':>10} {'As Name 2':>10}")
print("-" * 32)
for name in sorted(names):
    print(f"{name:<10} {position_counts['name1'][name]:>10} {position_counts['name2'][name]:>10}")

# Print most common name pairings
print("\n🔗 Most Common Name Pairs:")
for pair, count in pair_counts.most_common(10):
    print(f"{pair[0]} + {pair[1]}: {count} times")
# Out:
# 📌 Name Position Consistency:
# Name        As Name 1  As Name 2
# --------------------------------
# Avery              10          9
# Briar               7         11
# Harlow             11          8
# Harper              7         10
# Indigo             11          7
# Kendall            10          8
# Laramie            11          7
# Marley              7         11
# Payton              9         10
# Sage                7         11
# Wren               10          8
#
# 🔗 Most Common Name Pairs:
# Indigo + Sage: 5 times
# Payton + Wren: 5 times
# Harlow + Kendall: 4 times
# Harlow + Harper: 4 times
# Indigo + Kendall: 4 times
# Kendall + Sage: 4 times
# Laramie + Sage: 4 times
# Harper + Marley: 4 times
# Avery + Marley: 3 times
# Harper + Laramie: 3 times
