# %%
import json
import re
from docx import Document

def extract_scenarios(docx_path, output_json):
    scenarios = []
    doc = Document(docx_path)

    print(f"Total paragraphs found: {len(doc.paragraphs)}")

    pattern = re.compile(r'^Scenario\s*(\d+)[\.:]?\s*(.+)$')

    current_scenario = None

    for para in doc.paragraphs:
        line = para.text.strip()

        if not line:
            continue  # Skip empty lines

        print(f"Processing line: '{line}'")  # Debugging output

        match = pattern.match(line)
        if match:
            # Save the previous scenario before starting a new one
            if current_scenario:
                print(f"Adding scenario: {current_scenario['number']} - {current_scenario['title']}")  # Debugging
                scenarios.append(current_scenario)

            scenario_number = int(match.group(1))  # Extract number
            scenario_title = match.group(2).strip()  # Extract title

            current_scenario = {
                "number": scenario_number,
                "title": scenario_title,
                "description": []  # Description is an empty list initially
            }
            print(f"New scenario found: {scenario_number} - {scenario_title}")  # Debugging
        elif current_scenario:
            # Remove any quotation marks if present
            cleaned_line = line.strip('“”')  # Strip out leading and trailing quotation marks
            current_scenario["description"].append(cleaned_line)
            print(f"Description added: {cleaned_line}")  # Debugging

    # After the loop, add the last scenario
    if current_scenario:
        print(f"Adding final scenario: {current_scenario['number']} - {current_scenario['title']}")  # Debugging
        scenarios.append(current_scenario)

    # Debugging output: Check final scenarios before saving
    print(f"Final extracted scenarios: {json.dumps(scenarios, indent=4, ensure_ascii=False)}")

    # Save to JSON
    with open(output_json, 'w', encoding='utf-8') as json_file:
        json.dump(scenarios, json_file, indent=4, ensure_ascii=False)

    print(f"Extracted scenarios saved to: {output_json}")
    return scenarios

# Example usage
file_path = "C:/my place/PhD Scientific/PhD. Papers/ACL 2025/New Approach/Scenario list/Scenarios.docx"
output_json = "scenarios.json"
scenarios = extract_scenarios(file_path, output_json)
# Out:
# Total paragraphs found: 202
# Processing line: 'Scenario 1: Running a hairdressing salon'
# New scenario found: 1 - Running a hairdressing salon
# Processing line: '“Avery and Jordan are running a hairdressing salon together. Both take on key roles—Avery focusing on styling hair and Jordan managing operations. Avery consults clients, cuts and colors hair, and stays updated on trends. Jordan schedules appointments, orders supplies, and ensures a smooth workflow. Avery experiments with techniques, recommends treatments, and personalizes styles. Jordan handles customer service, manages finances, and promotes the salon. They collaborate on marketing, refine services based on feedback, and work together to create a welcoming atmosphere.”'
# Description added: Avery and Jordan are running a hairdressing salon together. Both take on key roles—Avery focusing on styling hair and Jordan managing operations. Avery consults clients, cuts and colors hair, and stays updated on trends. Jordan schedules appointments, orders supplies, and ensures a smooth workflow. Avery experiments with techniques, recommends treatments, and personalizes styles. Jordan handles customer service, manages finances, and promotes the salon. They collaborate on marketing, refine services based on feedback, and work together to create a welcoming atmosphere.
# Processing line: 'Scenario 2:  Startup Leadership'
# Adding scenario: 1 - Running a hairdressing salon
# New scenario found: 2 - Startup Leadership
# Processing line: '“Jordan and Taylor co-found a tech startup. Both are involved in the company's growth—Jordan focuses on securing funding, managing investor relations, overseeing marketing, and tracking expenses, while also driving business development. Taylor leads software development, tests prototypes, ensures product quality, and maintains workflow efficiency. Their roles are distinct but complementary, and they take a collaborative approach to strategic decision-making. Despite their different strategies, they work together to set goals for the company’s growth and success, maintaining open communication and mutual support to ensure their business thrives.”'
# Description added: Jordan and Taylor co-found a tech startup. Both are involved in the company's growth—Jordan focuses on securing funding, managing investor relations, overseeing marketing, and tracking expenses, while also driving business development. Taylor leads software development, tests prototypes, ensures product quality, and maintains workflow efficiency. Their roles are distinct but complementary, and they take a collaborative approach to strategic decision-making. Despite their different strategies, they work together to set goals for the company’s growth and success, maintaining open communication and mutual support to ensure their business thrives.
# Processing line: 'Scenario 3: Home renovation'
# Adding scenario: 2 - Startup Leadership
# New scenario found: 3 - Home renovation
# Processing line: '“Alex and Casey are renovating their home. Alex focuses on researching materials, comparing costs, sourcing supplies, and contacting contractors, while Casey handles logistics, supervises progress, schedules tasks, and ensures permits are in place. They take a collaborative approach to managing the renovation. Despite their different responsibilities, they work together to track expenses and stay on budget, setting shared goals to ensure the renovation is completed on time and within their financial plan. Through open communication and mutual support, they successfully navigate the challenges of home renovation.”'
# Description added: Alex and Casey are renovating their home. Alex focuses on researching materials, comparing costs, sourcing supplies, and contacting contractors, while Casey handles logistics, supervises progress, schedules tasks, and ensures permits are in place. They take a collaborative approach to managing the renovation. Despite their different responsibilities, they work together to track expenses and stay on budget, setting shared goals to ensure the renovation is completed on time and within their financial plan. Through open communication and mutual support, they successfully navigate the challenges of home renovation.
# Processing line: 'Scenario 4: Academic Research'
# Adding scenario: 3 - Home renovation
# New scenario found: 4 - Academic Research
# Processing line: '“Quinn and Avery are conducting academic research, each bringing their expertise to different aspects of the project. Quinn focuses on data collection, designing surveys, running analyses, and interpreting results, while Avery refines the research methodology, organizes sources, writes reports, and formats findings. They take a collaborative approach to refining their work. Despite their different responsibilities, they coordinate closely on revisions and prepare presentations together, ensuring their research is well-structured and effectively communicated. Through open communication and shared dedication, they work toward producing high-quality academic work.”'
# Description added: Quinn and Avery are conducting academic research, each bringing their expertise to different aspects of the project. Quinn focuses on data collection, designing surveys, running analyses, and interpreting results, while Avery refines the research methodology, organizes sources, writes reports, and formats findings. They take a collaborative approach to refining their work. Despite their different responsibilities, they coordinate closely on revisions and prepare presentations together, ensuring their research is well-structured and effectively communicated. Through open communication and shared dedication, they work toward producing high-quality academic work.
# Processing line: 'Scenario 5: Café Management'
# Adding scenario: 4 - Academic Research
# New scenario found: 5 - Café Management
# Processing line: '“Sky and Devon run a café, each contributing their expertise to different aspects of the business. Sky focuses on financial management, staff scheduling, and coordinating with suppliers, ensuring smooth day-to-day operations. Devon oversees menu development, enhances the customer experience, and maintains quality control to uphold the café’s standards. They take a collaborative approach to business management. Despite their different responsibilities, they regularly discuss improvements and align their goals to create a welcoming, innovative, and successful café. They work together to sustain and grow their thriving business.”'
# Description added: Sky and Devon run a café, each contributing their expertise to different aspects of the business. Sky focuses on financial management, staff scheduling, and coordinating with suppliers, ensuring smooth day-to-day operations. Devon oversees menu development, enhances the customer experience, and maintains quality control to uphold the café’s standards. They take a collaborative approach to business management. Despite their different responsibilities, they regularly discuss improvements and align their goals to create a welcoming, innovative, and successful café. They work together to sustain and grow their thriving business.
# Processing line: 'Scenario 6: Content creation partnership'
# Adding scenario: 5 - Café Management
# New scenario found: 6 - Content creation partnership
# Processing line: '“Drew and Jordan work as independent creatives, each contributing their expertise to different aspects of their projects. Drew focuses on content creation, writing articles, developing marketing strategies, and managing client outreach, while Jordan specializes in visual design, editing graphics, and ensuring branding consistency. Despite their different responsibilities, they regularly review projects together, aligning their creative vision to produce cohesive and high-quality results. Through open communication and shared dedication, they successfully balance their skills to meet client needs and achieve their professional goals.”'
# Description added: Drew and Jordan work as independent creatives, each contributing their expertise to different aspects of their projects. Drew focuses on content creation, writing articles, developing marketing strategies, and managing client outreach, while Jordan specializes in visual design, editing graphics, and ensuring branding consistency. Despite their different responsibilities, they regularly review projects together, aligning their creative vision to produce cohesive and high-quality results. Through open communication and shared dedication, they successfully balance their skills to meet client needs and achieve their professional goals.
# Processing line: 'Scenario 7: Community Garden Management'
# Adding scenario: 6 - Content creation partnership
# New scenario found: 7 - Community Garden Management
# Processing line: '“River and Morgan run a community garden, each contributing to different aspects of its success. River focuses on outreach, organizing volunteers, coordinating educational workshops, and planning community events, while Morgan handles garden upkeep, maintaining irrigation systems, overseeing planting, and ensuring soil health. They collaborate to garden management. Despite their different responsibilities, they work together to plan sustainable initiatives, fostering a thriving and inclusive green space. They create a welcoming environment for the community to engage with nature and sustainable gardening practices.”'
# Description added: River and Morgan run a community garden, each contributing to different aspects of its success. River focuses on outreach, organizing volunteers, coordinating educational workshops, and planning community events, while Morgan handles garden upkeep, maintaining irrigation systems, overseeing planting, and ensuring soil health. They collaborate to garden management. Despite their different responsibilities, they work together to plan sustainable initiatives, fostering a thriving and inclusive green space. They create a welcoming environment for the community to engage with nature and sustainable gardening practices.
# Processing line: 'Scenario 8: Nonprofit Management'
# Adding scenario: 7 - Community Garden Management
# New scenario found: 8 - Nonprofit Management
# Processing line: '“Taylor and Alex manage a nonprofit, each bringing their expertise to different aspects of the organization. Taylor focuses on networking, securing funding, applying for grants, and building strategic partnerships, while Alex oversees operations by coordinating volunteers, organizing impactful events, and managing daily tasks. They take a collaborative approach to leadership. Despite their different responsibilities, they work together to set and achieve long-term goals, ensuring the nonprofit’s sustainability and lasting impact. Through open communication and shared dedication, they foster a well-organized and mission-driven organization that serves its community effectively.”'
# Description added: Taylor and Alex manage a nonprofit, each bringing their expertise to different aspects of the organization. Taylor focuses on networking, securing funding, applying for grants, and building strategic partnerships, while Alex oversees operations by coordinating volunteers, organizing impactful events, and managing daily tasks. They take a collaborative approach to leadership. Despite their different responsibilities, they work together to set and achieve long-term goals, ensuring the nonprofit’s sustainability and lasting impact. Through open communication and shared dedication, they foster a well-organized and mission-driven organization that serves its community effectively.
# Processing line: 'Scenario 9: Band Leadership'
# Adding scenario: 8 - Nonprofit Management
# New scenario found: 9 - Band Leadership
# Processing line: '“Cameron and Riley play in a band, each taking on leadership roles in different aspects of its success. Cameron focuses on the musical side, writing original songs, scheduling rehearsals, and engaging with passionate fans, while Riley manages logistics by handling bookings, overseeing finances, and coordinating merchandise. Despite their different responsibilities, they take a collaborative approach on creative decisions, ensuring their music and brand evolve in alignment with their shared vision. Through open communication and mutual commitment, they balance artistic expression with the practical needs of their growing band.”'
# Description added: Cameron and Riley play in a band, each taking on leadership roles in different aspects of its success. Cameron focuses on the musical side, writing original songs, scheduling rehearsals, and engaging with passionate fans, while Riley manages logistics by handling bookings, overseeing finances, and coordinating merchandise. Despite their different responsibilities, they take a collaborative approach on creative decisions, ensuring their music and brand evolve in alignment with their shared vision. Through open communication and mutual commitment, they balance artistic expression with the practical needs of their growing band.
# Processing line: 'Scenario 10: Road Trip Planning'
# Adding scenario: 9 - Band Leadership
# New scenario found: 10 - Road Trip Planning
# Processing line: '“Sam and Casey are planning a road trip, each taking on key responsibilities to ensure a smooth journey. Sam focuses on mapping scenic routes, researching destinations, booking accommodations, and checking travel conditions, while Casey manages supplies by organizing packing, maintaining the vehicle, and tracking expenses. Despite their different tasks, they take a collaborative approach to finalize plans, making adjustments as needed to create a well-organized and enjoyable experience. Through open communication and shared enthusiasm, they work together to make their adventure both seamless and unforgettable.”'
# Description added: Sam and Casey are planning a road trip, each taking on key responsibilities to ensure a smooth journey. Sam focuses on mapping scenic routes, researching destinations, booking accommodations, and checking travel conditions, while Casey manages supplies by organizing packing, maintaining the vehicle, and tracking expenses. Despite their different tasks, they take a collaborative approach to finalize plans, making adjustments as needed to create a well-organized and enjoyable experience. Through open communication and shared enthusiasm, they work together to make their adventure both seamless and unforgettable.
# Processing line: 'Scenario 11: Short Film Production'
# Adding scenario: 10 - Road Trip Planning
# New scenario found: 11 - Short Film Production
# Processing line: '"Jordan Blake make a short film. Each contribute to different aspects of the project—Jordan focusing on direction and Blake on production. They take a collaborative approach to filmmaking process, with Jordan overseeing filming, working with talented actors, refining storytelling, exploring innovative techniques, making creative decisions, while Blake handling logistics, managing tight schedules, arranging necessary permits, securing locations, editing raw footage. They collaborate closely on the final cut, ensuring a cohesive and high-quality result through open communication, mutual trust, andclear goals."'
# Description added: "Jordan Blake make a short film. Each contribute to different aspects of the project—Jordan focusing on direction and Blake on production. They take a collaborative approach to filmmaking process, with Jordan overseeing filming, working with talented actors, refining storytelling, exploring innovative techniques, making creative decisions, while Blake handling logistics, managing tight schedules, arranging necessary permits, securing locations, editing raw footage. They collaborate closely on the final cut, ensuring a cohesive and high-quality result through open communication, mutual trust, andclear goals."
# Processing line: 'Scenario 12: Marketing partnership'
# Adding scenario: 11 - Short Film Production
# New scenario found: 12 - Marketing partnership
# Processing line: '“Alex and Quinn are launching a new product. Both focus on promotion—Alex on branding and Quinn on advertising. They take a collaborative approach, with Quinn focusing on data-driven campaign analysis and Alex exploring innovative creative engagement strategies. Quinn prefers traditional advertising metrics, while Alex enjoys experimenting with emerging social media trends. Despite their different strategies, they refine their marketing efforts together, ensuring a cohesive brand message, maintaining open communication, and driving success to achieve their shared goal of a highly successful product launch.”'
# Description added: Alex and Quinn are launching a new product. Both focus on promotion—Alex on branding and Quinn on advertising. They take a collaborative approach, with Quinn focusing on data-driven campaign analysis and Alex exploring innovative creative engagement strategies. Quinn prefers traditional advertising metrics, while Alex enjoys experimenting with emerging social media trends. Despite their different strategies, they refine their marketing efforts together, ensuring a cohesive brand message, maintaining open communication, and driving success to achieve their shared goal of a highly successful product launch.
# Processing line: 'Scenario 13: Restaurant co-ownership'
# Adding scenario: 12 - Marketing partnership
# New scenario found: 13 - Restaurant co-ownership
# Processing line: '“Sky and Taylor own a restaurant. Both take a collaborative approach to running the business—Sky focusing on operations and Taylor on food quality. Sky manages supplier relationships, staff scheduling, and overall efficiency, ensuring smooth daily operations. Taylor, on the other hand, curates the menu, oversees kitchen execution, and upholds culinary standards. Sky focuses on structured planning and logistics, while Taylor emphasizes creativity and consistency in the dining experience. They try to maintain open communication to regularly review finances, customer feedback, and operational performance together.”'
# Description added: Sky and Taylor own a restaurant. Both take a collaborative approach to running the business—Sky focusing on operations and Taylor on food quality. Sky manages supplier relationships, staff scheduling, and overall efficiency, ensuring smooth daily operations. Taylor, on the other hand, curates the menu, oversees kitchen execution, and upholds culinary standards. Sky focuses on structured planning and logistics, while Taylor emphasizes creativity and consistency in the dining experience. They try to maintain open communication to regularly review finances, customer feedback, and operational performance together.
# Processing line: 'Scenario 14: Household maintenance'
# Adding scenario: 13 - Restaurant co-ownership
# New scenario found: 14 - Household maintenance
# Processing line: '“Jordan and Morgan share an apartment. They take a collaborative approach to maintaining their apartment, each focusing on specific tasks. Jordan handles the daily cleaning, including vacuuming, taking out the trash, and wiping down surfaces. Morgan, on the other hand, manages laundry, organizing the kitchen, and ensuring the bathroom is tidy. Jordan focuses on keeping the space neat, organized, and orderly, while Morgan ensures everything is in place and fresh. They communicate regularly to keep the apartment running efficiently and ensure no task is overlooked, fostering a harmonious living environment.”'
# Description added: Jordan and Morgan share an apartment. They take a collaborative approach to maintaining their apartment, each focusing on specific tasks. Jordan handles the daily cleaning, including vacuuming, taking out the trash, and wiping down surfaces. Morgan, on the other hand, manages laundry, organizing the kitchen, and ensuring the bathroom is tidy. Jordan focuses on keeping the space neat, organized, and orderly, while Morgan ensures everything is in place and fresh. They communicate regularly to keep the apartment running efficiently and ensure no task is overlooked, fostering a harmonious living environment.
# Processing line: 'Scenario 15: Graphic design studio co-ownership'
# Adding scenario: 14 - Household maintenance
# New scenario found: 15 - Graphic design studio co-ownership
# Processing line: '“Jordan and Casey co-own a graphic design studio. Both take a collaborative approach to running the business—Jordan focusing on client relations and Casey on creative direction. Jordan manages client communications, handles project timelines, and ensures the smooth flow of deliverables, keeps track of the studio’s contracts and client satisfaction. Casey, on the other hand, leads the design process, curates the studio's visual identity, and refines the creative output. Together, they regularly review project progress, budget management, and client feedback to ensure continuous success and growth.”'
# Description added: Jordan and Casey co-own a graphic design studio. Both take a collaborative approach to running the business—Jordan focusing on client relations and Casey on creative direction. Jordan manages client communications, handles project timelines, and ensures the smooth flow of deliverables, keeps track of the studio’s contracts and client satisfaction. Casey, on the other hand, leads the design process, curates the studio's visual identity, and refines the creative output. Together, they regularly review project progress, budget management, and client feedback to ensure continuous success and growth.
# Processing line: 'Scenario 16: Trip organizing'
# Adding scenario: 15 - Graphic design studio co-ownership
# New scenario found: 16 - Trip organizing
# Processing line: '“Casey and Avery are organizing a trip, each focusing on different aspects. Casey handles travel logistics, comparing flight options, booking hotels, and managing documents. Avery plans activities, researching local attractions, arranging sightseeing, and coordinating with guides. While Casey ensures smooth transportation and accommodations, Avery creates a memorable experience through carefully planned excursions and dining recommendations. They maintain open communication, adjusting plans as needed, reviewing the budget, and ensuring every detail aligns to create a seamless and enjoyable trip.”'
# Description added: Casey and Avery are organizing a trip, each focusing on different aspects. Casey handles travel logistics, comparing flight options, booking hotels, and managing documents. Avery plans activities, researching local attractions, arranging sightseeing, and coordinating with guides. While Casey ensures smooth transportation and accommodations, Avery creates a memorable experience through carefully planned excursions and dining recommendations. They maintain open communication, adjusting plans as needed, reviewing the budget, and ensuring every detail aligns to create a seamless and enjoyable trip.
# Processing line: 'Scenario 17: Meal cooking'
# Adding scenario: 16 - Trip organizing
# New scenario found: 17 - Meal cooking
# Processing line: '“Quinn and Drew cook at home. Both enjoy different roles—Quinn focusing on meal planning and Drew on cooking. Quinn selects recipes, creates grocery lists, and ensures dietary needs are met, while Drew handles meal preparation, experiments with new dishes, and manages leftovers. Their approaches to cooking differ—Quinn prefers structured meal plans, while Drew enjoys creating in the kitchen. Despite their different methods, they collaborate on meal choices and share the workload, swapping roles on weekends to keep things balanced, efficient, and enjoyable..”'
# Description added: Quinn and Drew cook at home. Both enjoy different roles—Quinn focusing on meal planning and Drew on cooking. Quinn selects recipes, creates grocery lists, and ensures dietary needs are met, while Drew handles meal preparation, experiments with new dishes, and manages leftovers. Their approaches to cooking differ—Quinn prefers structured meal plans, while Drew enjoys creating in the kitchen. Despite their different methods, they collaborate on meal choices and share the workload, swapping roles on weekends to keep things balanced, efficient, and enjoyable..
# Processing line: 'Scenario 18: Library collaboration'
# Adding scenario: 17 - Meal cooking
# New scenario found: 18 - Library collaboration
# Processing line: '“Morgan and Devon work in a library. They take a collaborative approach to handling responsibilities—Morgan focusing on digitizing records and Devon on organizing physical books. Morgan scans and categorizes historical documents, converting them into digital formats, while Devon arranges books on shelves, labels sections, and updates the library catalog to ensure everything is easy to find. They collaborate closely, ensuring that both the digital and physical collections are accessible, well-maintained, and properly organized. They meet regularly to discuss improvements, share innovative ideas, and adjust workflows for maximum efficiency.”'
# Description added: Morgan and Devon work in a library. They take a collaborative approach to handling responsibilities—Morgan focusing on digitizing records and Devon on organizing physical books. Morgan scans and categorizes historical documents, converting them into digital formats, while Devon arranges books on shelves, labels sections, and updates the library catalog to ensure everything is easy to find. They collaborate closely, ensuring that both the digital and physical collections are accessible, well-maintained, and properly organized. They meet regularly to discuss improvements, share innovative ideas, and adjust workflows for maximum efficiency.
# Processing line: 'Scenario 19: Workout partnership'
# Adding scenario: 18 - Library collaboration
# New scenario found: 19 - Workout partnership
# Processing line: '“Sky and Blake are workout partners. Both keep an eye on fitness goals—Sky focusing on endurance and Blake on strength. Sky leads intense cardio sessions, tracks running progress, and monitors stamina levels to ensure improvement. Blake, on the other hand, supervises weightlifting routines, and plans strength-building exercises to target specific muscle groups. They adjust their workouts as needed, based on their individual progress, ensuring each session is effective and challenging. Together, they maintain open communication to balance their training, pushing each other to reach their ultimate fitness goals.”'
# Description added: Sky and Blake are workout partners. Both keep an eye on fitness goals—Sky focusing on endurance and Blake on strength. Sky leads intense cardio sessions, tracks running progress, and monitors stamina levels to ensure improvement. Blake, on the other hand, supervises weightlifting routines, and plans strength-building exercises to target specific muscle groups. They adjust their workouts as needed, based on their individual progress, ensuring each session is effective and challenging. Together, they maintain open communication to balance their training, pushing each other to reach their ultimate fitness goals.
# Processing line: 'Scenario 20: E-commerce partnership'
# Adding scenario: 19 - Workout partnership
# New scenario found: 20 - E-commerce partnership
# Processing line: '“Jordan and Casey run an e-commerce store. Both manage key operations—Jordan focusing on sales and Casey overseeing logistics. Jordan updates product listings, writes engaging descriptions, and communicates with customers to address inquiries and feedback. Casey, on the other hand, handles packing orders, arranging shipping, and tracking deliveries to ensure everything reaches customers on time. They analyze sales trends together, making data-driven decisions to optimize inventory and improve customer satisfaction. Regularly reviewing performance helps them adjust strategies and streamline operations for growth.”'
# Description added: Jordan and Casey run an e-commerce store. Both manage key operations—Jordan focusing on sales and Casey overseeing logistics. Jordan updates product listings, writes engaging descriptions, and communicates with customers to address inquiries and feedback. Casey, on the other hand, handles packing orders, arranging shipping, and tracking deliveries to ensure everything reaches customers on time. They analyze sales trends together, making data-driven decisions to optimize inventory and improve customer satisfaction. Regularly reviewing performance helps them adjust strategies and streamline operations for growth.
# Processing line: 'Scenario 21: Event planning'
# Adding scenario: 20 - E-commerce partnership
# New scenario found: 21 - Event planning
# Processing line: '“Avery and Taylor organize events. They take a collaborative approach in organizing events and split responsibilities—Avery focusing on logistics and Taylor handling promotions. Avery books venues, arranges catering, and creates detailed timelines to ensure the event runs smoothly. Taylor designs eye-catching invitations, markets the event across different platforms, and manages guest lists to ensure the right people are invited. After each event, they review feedback together to identify areas for improvement, ensuring their future events are even more successful, well-coordinated, and impactful.”'
# Description added: Avery and Taylor organize events. They take a collaborative approach in organizing events and split responsibilities—Avery focusing on logistics and Taylor handling promotions. Avery books venues, arranges catering, and creates detailed timelines to ensure the event runs smoothly. Taylor designs eye-catching invitations, markets the event across different platforms, and manages guest lists to ensure the right people are invited. After each event, they review feedback together to identify areas for improvement, ensuring their future events are even more successful, well-coordinated, and impactful.
# Processing line: 'Scenario 22: Pet care'
# Adding scenario: 21 - Event planning
# New scenario found: 22 - Pet care
# Processing line: '“Jordan and Quinn have a pet and share responsibilities to ensure its well-being—Jordan focusing on feeding and health, while Quinn manages exercise and engagement. Jordan prepares nutritious meals, tracks the pet’s diet, and schedules regular vet visits to monitor overall health. Quinn takes the pet for daily walks, engages in interactive playtime, and reinforces positive training routines for consistency. They communicate regularly, discuss behavioral changes or concerns, and adjust their care routine as needed to provide the best possible life for their pet.”'
# Description added: Jordan and Quinn have a pet and share responsibilities to ensure its well-being—Jordan focusing on feeding and health, while Quinn manages exercise and engagement. Jordan prepares nutritious meals, tracks the pet’s diet, and schedules regular vet visits to monitor overall health. Quinn takes the pet for daily walks, engages in interactive playtime, and reinforces positive training routines for consistency. They communicate regularly, discuss behavioral changes or concerns, and adjust their care routine as needed to provide the best possible life for their pet.
# Processing line: 'Scenario 23: Leading a community clean up'
# Adding scenario: 22 - Pet care
# New scenario found: 23 - Leading a community clean up
# Processing line: '“Casey and Morgan lead a community cleanup, each playing a vital role in its success—with Casey focusing on volunteer coordination and Morgan handling logistics. Casey recruits helpers, spreads awareness through promotions, and tracks progress to keep participants engaged. Morgan gathers necessary supplies, arranges waste disposal, and assigns tasks to ensure efficiency. While Casey fosters community involvement, Morgan ensures operations run smoothly. After each event, they review outcomes, discuss improvements, and plan future initiatives mutually to maximize their impact.”'
# Description added: Casey and Morgan lead a community cleanup, each playing a vital role in its success—with Casey focusing on volunteer coordination and Morgan handling logistics. Casey recruits helpers, spreads awareness through promotions, and tracks progress to keep participants engaged. Morgan gathers necessary supplies, arranges waste disposal, and assigns tasks to ensure efficiency. While Casey fosters community involvement, Morgan ensures operations run smoothly. After each event, they review outcomes, discuss improvements, and plan future initiatives mutually to maximize their impact.
# Processing line: 'Scenario 24: Retail store management'
# Adding scenario: 23 - Leading a community clean up
# New scenario found: 24 - Retail store management
# Processing line: '“Blake and Sky work in a store, each focusing on key aspects—Blake handling operations and Sky handling customer service. Blake monitors inventory levels, sets competitive pricing, and ensures transactions are efficient and accurate. Sky interacts with customers, provides assistance, resolves complaints, and enhances the overall shopping experience. While Blake keeps the backend organized, Sky ensures the storefront remains welcoming and engaging. They regularly analyse sales trends together, adjusting strategies to improve efficiency, customer satisfaction, and overall performance.”'
# Description added: Blake and Sky work in a store, each focusing on key aspects—Blake handling operations and Sky handling customer service. Blake monitors inventory levels, sets competitive pricing, and ensures transactions are efficient and accurate. Sky interacts with customers, provides assistance, resolves complaints, and enhances the overall shopping experience. While Blake keeps the backend organized, Sky ensures the storefront remains welcoming and engaging. They regularly analyse sales trends together, adjusting strategies to improve efficiency, customer satisfaction, and overall performance.
# Processing line: 'Scenario 25: Moving to a new place'
# Adding scenario: 24 - Retail store management
# New scenario found: 25 - Moving to a new place
# Processing line: '“Riley and Drew are moving to a new place, each taking on specific responsibilities—Riley organizing packing and Drew managing transportation. Riley categorizes items, sorts through belongings to donate unused things, and secures boxes to ensure everything is neatly packed. Drew rents a truck, coordinates timing to ensure a smooth move, and carefully handles items to prevent damage. Once the move is complete, they unpack together, setting up their new home efficiently and ensuring everything has its place. They also clean the space, organize utilities, and finalize any outstanding tasks.”'
# Description added: Riley and Drew are moving to a new place, each taking on specific responsibilities—Riley organizing packing and Drew managing transportation. Riley categorizes items, sorts through belongings to donate unused things, and secures boxes to ensure everything is neatly packed. Drew rents a truck, coordinates timing to ensure a smooth move, and carefully handles items to prevent damage. Once the move is complete, they unpack together, setting up their new home efficiently and ensuring everything has its place. They also clean the space, organize utilities, and finalize any outstanding tasks.
# Processing line: 'Scenario 26: Language Learning partners'
# Adding scenario: 25 - Moving to a new place
# New scenario found: 26 - Language Learning partners
# Processing line: '“Taylor and Cameron are learning a new language, each using a different approach—Taylor focusing on speaking and Cameron on writing. Taylor practices conversations, listens to native speakers, and memorizes useful phrases to improve fluency. Cameron studies grammar rules, completes writing exercises, and expands their vocabulary for better sentence structure. They support each other’s progress by testing one another weekly, combining their strengths to develop well-rounded language skills. Their collaboration keeps them motivated and helps them learn more effectively, track milestones, and refine their pronunciation.”'
# Description added: Taylor and Cameron are learning a new language, each using a different approach—Taylor focusing on speaking and Cameron on writing. Taylor practices conversations, listens to native speakers, and memorizes useful phrases to improve fluency. Cameron studies grammar rules, completes writing exercises, and expands their vocabulary for better sentence structure. They support each other’s progress by testing one another weekly, combining their strengths to develop well-rounded language skills. Their collaboration keeps them motivated and helps them learn more effectively, track milestones, and refine their pronunciation.
# Processing line: 'Scenario 27: eSport partnership'
# Adding scenario: 26 - Language Learning partners
# New scenario found: 27 - eSport partnership
# Processing line: '“Devon and Morgan compete in eSports, each playing a crucial role in their team’s success—Devon focusing on strategy and Morgan on practice management. Devon studies opponents, refines game plans, and leads tactical discussions to improve gameplay. Morgan organizes practice schedules, reviews performance metrics, and keeps team morale high to maintain focus and motivation. While Devon ensures smart in-game decisions, Morgan optimizes preparation and teamwork. They analyze match results together, adjusting tactics to stay competitive and make sure they are improving.”'
# Description added: Devon and Morgan compete in eSports, each playing a crucial role in their team’s success—Devon focusing on strategy and Morgan on practice management. Devon studies opponents, refines game plans, and leads tactical discussions to improve gameplay. Morgan organizes practice schedules, reviews performance metrics, and keeps team morale high to maintain focus and motivation. While Devon ensures smart in-game decisions, Morgan optimizes preparation and teamwork. They analyze match results together, adjusting tactics to stay competitive and make sure they are improving.
# Processing line: 'Scenario 28: Speech preparation'
# Adding scenario: 27 - eSport partnership
# New scenario found: 28 - Speech preparation
# Processing line: '“Jordan and Sky are preparing a speech for their project, each contributing to a different aspect—Jordan focusing on delivery and Sky on content structure. Jordan practices tone, refines body language, and improves voice projection to enhance audience engagement. Sky organizes key points, ensures clarity, and adjusts timing for a smooth, effective flow. While Jordan brings confidence and presence to the speech, Sky fine-tunes the message for maximum impact. They rehearse together, providing constructive feedback and making necessary adjustments until they feel fully prepared and polished.”'
# Description added: Jordan and Sky are preparing a speech for their project, each contributing to a different aspect—Jordan focusing on delivery and Sky on content structure. Jordan practices tone, refines body language, and improves voice projection to enhance audience engagement. Sky organizes key points, ensures clarity, and adjusts timing for a smooth, effective flow. While Jordan brings confidence and presence to the speech, Sky fine-tunes the message for maximum impact. They rehearse together, providing constructive feedback and making necessary adjustments until they feel fully prepared and polished.
# Processing line: 'Scenario 29: Home office set up'
# Adding scenario: 28 - Speech preparation
# New scenario found: 29 - Home office set up
# Processing line: '“Quinn and Avery are setting up a home office, each focusing on different aspects—Quinn designing the space and Avery managing technology. Quinn arranges furniture, optimizes lighting, and decorates to create a comfortable and inspiring workspace. Avery sets up computers, installs essential software, configures networks, and ensures internet reliability for seamless connectivity. While Quinn enhances organization and aesthetics, Avery focuses on functionality, technical efficiency, and system integration. They collaborate to adjust the layout as needed, ensuring the space is both productive and visually appealing.”'
# Description added: Quinn and Avery are setting up a home office, each focusing on different aspects—Quinn designing the space and Avery managing technology. Quinn arranges furniture, optimizes lighting, and decorates to create a comfortable and inspiring workspace. Avery sets up computers, installs essential software, configures networks, and ensures internet reliability for seamless connectivity. While Quinn enhances organization and aesthetics, Avery focuses on functionality, technical efficiency, and system integration. They collaborate to adjust the layout as needed, ensuring the space is both productive and visually appealing.
# Processing line: 'Scenario 30: Co-writing a book'
# Adding scenario: 29 - Home office set up
# New scenario found: 30 - Co-writing a book
# Processing line: '“Casey and Drew are writing a book, each contributing their strengths—Casey focusing on story development and Drew on editing. Casey drafts chapters, develops characters, structures the plot, and outlines key events to create a compelling narrative. Drew refines grammar, ensures consistency, polishes the language, checks for errors, and improves sentence structure to enhance clarity and flow. While Casey brings creativity and storytelling, Drew provides precision and refinement. They collaborate in reviewing each draft, making revisions, and perfecting details until they are fully satisfied with the final manuscript.”'
# Description added: Casey and Drew are writing a book, each contributing their strengths—Casey focusing on story development and Drew on editing. Casey drafts chapters, develops characters, structures the plot, and outlines key events to create a compelling narrative. Drew refines grammar, ensures consistency, polishes the language, checks for errors, and improves sentence structure to enhance clarity and flow. While Casey brings creativity and storytelling, Drew provides precision and refinement. They collaborate in reviewing each draft, making revisions, and perfecting details until they are fully satisfied with the final manuscript.
# Processing line: 'Scenario 31: Shelter co-workers'
# Adding scenario: 30 - Co-writing a book
# New scenario found: 31 - Shelter co-workers
# Processing line: '“Taylor and Riley help at a shelter, each focusing on different responsibilities—Taylor organizing resources and Riley working directly with residents. Taylor sorts donations, manages supplies, and coordinates volunteer efforts to ensure operations run smoothly. Riley distributes meals, listens to residents’ concerns, and assists with paperwork to provide necessary support. While Taylor maintains structure and organization, Riley offers hands-on assistance and emotional support. After each shift, they debrief together, discussing challenges, sharing insights, and finding ways to improve their work.”'
# Description added: Taylor and Riley help at a shelter, each focusing on different responsibilities—Taylor organizing resources and Riley working directly with residents. Taylor sorts donations, manages supplies, and coordinates volunteer efforts to ensure operations run smoothly. Riley distributes meals, listens to residents’ concerns, and assists with paperwork to provide necessary support. While Taylor maintains structure and organization, Riley offers hands-on assistance and emotional support. After each shift, they debrief together, discussing challenges, sharing insights, and finding ways to improve their work.
# Processing line: 'Scenario 32: car ownership'
# Adding scenario: 31 - Shelter co-workers
# New scenario found: 32 - car ownership
# Processing line: '“Blake and Cameron take care of their car, each focusing on different aspects—Blake handling inspections and Cameron managing cleanliness. Blake checks oil levels, monitors tire pressure, schedules regular servicing, and tracks repairs to ensure the car runs smoothly. Cameron takes care of cleaning the interior, washing the exterior, organizing the trunk, and vacuuming the seats to keep everything tidy. They work together to maintain maintenance records, ensuring their car remains in top condition and stays reliable for every journey.”'
# Description added: Blake and Cameron take care of their car, each focusing on different aspects—Blake handling inspections and Cameron managing cleanliness. Blake checks oil levels, monitors tire pressure, schedules regular servicing, and tracks repairs to ensure the car runs smoothly. Cameron takes care of cleaning the interior, washing the exterior, organizing the trunk, and vacuuming the seats to keep everything tidy. They work together to maintain maintenance records, ensuring their car remains in top condition and stays reliable for every journey.
# Processing line: 'Scenario 33: Planning a hiking trip'
# Adding scenario: 32 - car ownership
# New scenario found: 33 - Planning a hiking trip
# Processing line: '“Jordan and Devon plan a hiking trip, each taking charge of different tasks—Jordan researching trails and Devon organizing gear. Jordan checks trail difficulty, reviews weather forecasts, ensures all safety guidelines are followed, and identifies potential hazards for a secure experience. Devon packs essential equipment, arranges food, makes sure first-aid supplies are ready, and coordinates with local guides in case of emergencies. They communicate about potential risks, review emergency plans, and ensure everything is prepared for a safe and enjoyable adventure in the great outdoors.”'
# Description added: Jordan and Devon plan a hiking trip, each taking charge of different tasks—Jordan researching trails and Devon organizing gear. Jordan checks trail difficulty, reviews weather forecasts, ensures all safety guidelines are followed, and identifies potential hazards for a secure experience. Devon packs essential equipment, arranges food, makes sure first-aid supplies are ready, and coordinates with local guides in case of emergencies. They communicate about potential risks, review emergency plans, and ensure everything is prepared for a safe and enjoyable adventure in the great outdoors.
# Processing line: 'Scenario 34: science project partnership'
# Adding scenario: 33 - Planning a hiking trip
# New scenario found: 34 - science project partnership
# Processing line: '“Morgan and Sky are working on a science project, each focusing on key tasks—Morgan conducting experiments and Sky documenting the entire process. Morgan sets up tests, adjusts variables, records results, analyzes data, and monitors outcomes to gather valuable insights. Sky writes detailed reports, prepares visuals like charts or graphs, structures the final presentation, and organizes findings to ensure clear communication. They collaborate by practicing their explanation together, refining how they present the project to ensure it’s informative, engaging, and accurate for their audience.”'
# Description added: Morgan and Sky are working on a science project, each focusing on key tasks—Morgan conducting experiments and Sky documenting the entire process. Morgan sets up tests, adjusts variables, records results, analyzes data, and monitors outcomes to gather valuable insights. Sky writes detailed reports, prepares visuals like charts or graphs, structures the final presentation, and organizes findings to ensure clear communication. They collaborate by practicing their explanation together, refining how they present the project to ensure it’s informative, engaging, and accurate for their audience.
# Processing line: 'Scenario 35: Redecorating an apartment'
# Adding scenario: 34 - science project partnership
# New scenario found: 35 - Redecorating an apartment
# ...
#         "title": "Designing a mini-golf course",
#         "description": [
#             "Sky and Taylor are designing a mini-golf course. Both contribute to different aspects—Sky creating obstacles and Taylor managing logistics. Sky designs challenging holes, tests layouts, and adds creative themes. Taylor arranges course setup, coordinates schedules, handles marketing, and manages budgeting. Sky ensures the obstacles are fun and engaging, while Taylor makes sure the experience runs smoothly for players. They review feedback from visitors to refine and improve the course, making adjustments to both the design and logistics to ensure a memorable and well-organized experience for all."
#         ]
#     },
#     {
#         "number": 80,
#         "title": "Maintaining an urban beehive",
#         "description": [
#             "Jordan and Drew maintain an urban beehive. Both have duties—Jordan monitoring the hive and Drew harvesting honey. Jordan inspects colony health, checks for pests, manages hive expansion, and tracks bee activity. Drew extracts honey, filters wax, and packages products for sale. Jordan ensures the bees have a sustainable environment, while Drew maintains equipment and storage. They collaborate on seasonal management, adjusting care based on weather, nectar flow, and hive conditions. Together, they educate the community on pollination, environmental responsibility, and the importance of urban beekeeping."
#         ]
#     },
#     {
#         "number": 81,
#         "title": "Organizing a coastal cleanup",
#         "description": [
#             "Avery and Riley organize a coastal cleanup. Both take roles—Avery coordinating volunteers and Riley handling logistics. Avery promotes the event, gathers sponsors, and tracks participation numbers. Riley distributes cleanup tools, sorts collected waste, and ensures proper recycling and disposal. Avery communicates with local organizations to gain support, while Riley arranges transportation for debris removal. They document progress, analyze collected data, and report results to the community. Together, they work to raise awareness and enhance environmental conservation efforts along the coastline."
#         ]
#     },
#     {
#         "number": 82,
#         "title": "Home business",
#         "description": [
#             "Blake and Quinn create organic soaps. Both share tasks—Blake experimenting with formulas and Quinn handling packaging. Blake selects natural ingredients, tests scent combinations, and refines recipes for quality. Quinn designs labels, wraps bars, and creates appealing product displays. Blake researches skin benefits and ensures sustainability, while Quinn manages branding and promotions. They collaborate on pricing, production efficiency, and expanding their product line. Together, they track customer feedback and adjust formulas or designs to meet consumer preferences and market demand."
#         ]
#     },
#     {
#         "number": 83,
#         "title": "Organizing a film festival",
#         "description": [
#             "Cameron and Casey are organizing a film festival. Both contribute—Cameron curating films and Casey managing event logistics. Cameron selects movies, researches directors, and arranges Q&A sessions. Casey secures venues, coordinates screening schedules, and oversees ticket sales. Cameron ensures a diverse lineup, balancing genres and themes, while Casey handles permits, seating, and technical setups. They collaborate on marketing, reaching out to press and engaging audiences effectively. After the event, they gather feedback, analyze attendance, and discuss potential improvements for future festivals."
#         ]
#     },
#     {
#         "number": 84,
#         "title": "Fixing old electronics",
#         "description": [
#             "Morgan and Sky fix old electronics. Both take charge—Morgan diagnosing issues and Sky handling repairs. Morgan researches common problems, tests circuits, and sources replacement parts. Sky disassembles devices, replaces faulty components, and reassembles gadgets. Morgan ensures compatibility, troubleshoots errors, and fine-tunes performance. Sky cleans connections, checks wiring, and optimizes durability. They document fixes, share solutions, and improve efficiency over time. Before finalizing, they conduct thorough functionality tests to confirm proper operation and ensure reliability for long-term use."
#         ]
#     },
#     {
#         "number": 85,
#         "title": "Fashion brand co-ownership",
#         "description": [
#             "Taylor and Jordan are launching an eco-friendly fashion brand. Both have roles—Taylor designing apparel and Jordan sourcing materials. Taylor sketches outfits, chooses fabrics, and ensures comfort and style. Jordan researches sustainable materials, negotiates with ethical suppliers, and oversees production costs. Taylor focuses on innovative designs, keeping environmental impact in mind. Jordan ensures the brand’s supply chain supports fair trade practices and minimal waste. They collaborate to create a brand that champions responsible consumption, promoting eco-conscious choices in the fashion industry."
#         ]
#     },
#     {
#         "number": 86,
#         "title": "Running a bookstore",
#         "description": [
#             "Drew and Avery run a bookstore. Both divide tasks—Drew handling inventory and Avery engaging with customers. Drew orders books, tracks stock, manages suppliers, and ensures the bookstore is always stocked. Avery arranges displays, hosts events like author readings, and offers personalized book recommendations to customers. Drew monitors trends and adapts inventory accordingly. Avery builds strong customer relationships, creating a welcoming atmosphere. Together, they ensure to stay current with literary trends and deliver a great customer experience."
#         ]
#     },
#     {
#         "number": 87,
#         "title": "Animal rescue",
#         "description": [
#             "Blake and Casey help at an animal rescue. Both contribute—Blake assisting with adoptions and Casey caring for animals. Blake processes adoption applications, conducts interviews with potential adopters, and handles the necessary paperwork. Casey is responsible for feeding, grooming, and socializing the animals, ensuring they are well cared for and healthy. Together, they create a seamless adoption process, managing records, matching pets with loving homes. They work closely to ensure the animals’ needs are met while providing adopters with the support, education, and guidance they need throughout the process."
#         ]
#     },
#     {
#         "number": 88,
#         "title": "Hosting a cooking class",
#         "description": [
#             "Morgan and Quinn host a cooking class. Both take charge based on their experties—Morgan planning recipes and Quinn managing the class. Morgan selects dishes, researches techniques, and prepares demonstrations. Quinn organizes the class schedule, sets up equipment, and ensures participants stay on track. Morgan provides guidance, answers questions, and helps with cooking tips. Quinn assists with hands-on tasks, keeps the environment organized, and makes sure everyone is comfortable. Afterward, they gather feedback and adjust the class for a better learning experience."
#         ]
#     },
#     {
#         "number": 89,
#         "title": "Home renovation",
#         "description": [
#             "Sky and Taylor are renovating their home. Both take tasks—Sky handling demolition and Taylor focusing on rebuilding. Sky tears down old structures, removes debris, and preps surfaces for upgrades. Taylor installs new fixtures, paints walls, and lays flooring. Sky ensures proper disposal of materials, checks for structural stability, and clears space for renovations. Taylor measures dimensions, selects finishes, and refines details. They collaborate on design choices, balance aesthetics with function, and make adjustments as needed to complete their renovation successfully."
#         ]
#     },
#     {
#         "number": 90,
#         "title": "Organizimg a local play",
#         "description": [
#             "Jordan and Drew put on a local play. Both contribute—Jordan designing costumes and Drew managing lighting. Jordan researches period styles, selects fabrics, and tailors outfits to fit the cast. Drew programs lighting cues, adjusts intensity, and creates mood-enhancing effects. Jordan ensures each costume aligns with the character’s role, adds finishing touches, and oversees quick changes. Drew coordinates with the director, troubleshoots technical issues, and fine-tunes transitions. They work closely with the cast to ensure a seamless and visually stunning performance."
#         ]
#     },
#     {
#         "number": 91,
#         "title": "Co-assisting a hospital ward",
#         "description": [
#             "Morgan and Casey assist in a busy hospital ward. Both take roles—Morgan managing patient care and Casey handling medical records. Morgan checks vital signs, administers medications, and communicates with doctors. Casey updates charts, processes test results, and ensures documentation. Morgan monitors patient progress, responds to emergencies, and provides comfort. Casey schedules procedures, coordinates with departments, and maintains compliance with protocols. They collaborate to ensure smooth operations, efficient treatment, and high-quality patient care, working together to improve health outcomes."
#         ]
#     },
#     {
#         "number": 92,
#         "title": "Developing a mobile application",
#         "description": [
#             "Morgan and Casey are developing a new mobile application. Both share responsibilities—Morgan handling the user interface and Casey managing the backend. Morgan designs the layout, creates wireframes, and tests interactions, ensuring the app’s functionality is intuitive. Casey writes code, troubleshoots issues, ensures data security, and optimizes performance. They collaborate to integrate new features, refine design, and streamline the user experience. Morgan leads usability tests, while Casey implements updates. Together, they monitor feedback and continuously make improvements to create a seamless, user-friendly application."
#         ]
#     },
#     {
#         "number": 93,
#         "title": "Co-Teaching a Class",
#         "description": [
#             "Jordan and Taylor are co-teaching a class. Both take on distinct roles—Jordan leading discussions and Taylor managing activities. Jordan explains concepts, facilitates group conversations, and answers questions. Taylor prepares materials, organizes hands-on exercises, and ensures student engagement. They collaborate on lesson plans, adjust pacing based on student needs, and offer support individually. Jordan monitors student progress during lectures, while Taylor provides feedback during assignments. Together, they create an inclusive learning environment and assess students’ understanding, ensuring effective teaching outcomes."
#         ]
#     },
#     {
#         "number": 94,
#         "title": "Co-writing a research paper",
#         "description": [
#             "Blake and Riley work on a research paper. Both focus on different tasks—Blake gathering research and Riley writing the content. Blake searches academic journals, collects data, and synthesizes findings. Riley drafts the introduction, writes analysis sections, and ensures the paper’s clarity. They collaborate on outlining key points, revising drafts, and refining the methodology. Blake double-checks the references, while Riley ensures proper formatting and consistency. Together, they review the paper, revise the conclusions, and finalize it for submission, ensuring accuracy, quality, and coherence."
#         ]
#     },
#     {
#         "number": 95,
#         "title": "Medical laboratory collaboration",
#         "description": [
#             "Blake and Avery work together in a medical laboratory to conduct tests. Both have distinct roles—Blake handling sample collection and Avery analyzing results. Blake prepares specimens, labels samples, and ensures proper handling. Avery runs diagnostic tests, interprets data, and records findings. They collaborate to maintain lab equipment, verify accuracy, and troubleshoot any issues. Blake monitors quality control procedures, while Avery compiles reports and ensures compliance with health standards. Together, they work to provide accurate and timely results for patient care."
#         ]
#     },
#     {
#         "number": 96,
#         "title": "Childcare",
#         "description": [
#             "Blake and Riley share childcare duties at home. Both take on different roles—Blake managing daily routines and Riley handling activities. Blake prepares meals, ensures nap times, and oversees homework. Riley plans playdates, organizes educational games, and reads books. They communicate about children's needs, monitor progress, and ensure safety. Blake tracks health appointments and schedules, while Riley addresses emotional and social well-being. Together, they create a balanced environment by maintaining structure and providing fun, fostering a nurturing atmosphere for their children's development."
#         ]
#     },
#     {
#         "number": 97,
#         "title": "Running  a farm",
#         "description": [
#             "Blake and Morgan are running a small farm together. Both take on different responsibilities—Blake managing crops and Morgan tending to animals. Blake plants seeds, monitors growth, and harvests produce. Morgan feeds livestock, collects eggs, and ensures animal health. They work together to maintain equipment, repair fences, and plan seasonal tasks. Blake tracks inventory and markets produce, while Morgan focuses on breeding and caring for the animals. Together, they create a self-sustaining farm by balancing crop production with animal husbandry."
#         ]
#     },
#     {
#         "number": 98,
#         "title": "Leading a book club",
#         "description": [
#             "Morgan and Quinn lead a vibrant book club, with each taking on key responsibilities. Morgan is in charge of selecting books, researching titles, and organizing the reading schedule to ensure variety. While Morgan provides detailed summaries to enhance understanding, Quinn facilitates discussions by encouraging participation, moderating talks, and tracking key themes throughout the books. Together, they collaborate to adapt to the interests and preferences of club members, adjusting their approach to keep discussions lively, inclusive, and relevant to everyone’s reading experiences."
#         ]
#     },
#     {
#         "number": 99,
#         "title": "Leading a construction project",
#         "description": [
#             "Morgan and Taylor lead a construction project. Both take charge—Morgan overseeing the design and Taylor managing construction. Morgan works with architects, finalizes blueprints, and ensures the design aligns with community needs. Taylor coordinates labor, supervises contractors, and monitors the construction process. Morgan handles permits, safety regulations, and budget allocation, while Taylor ensures deadlines are met, materials are ordered, and quality is maintained. Together, they oversee the project’s completion, making adjustments as needed to stay on track and within budget."
#         ]
#     },
#     {
#         "number": 100,
#         "title": "Managing a local delivery system",
#         "description": [
#             "Morgan and Riley are managing a local delivery system. Both have key roles—Morgan handling logistics and Riley overseeing drivers. Morgan plans routes, tracks orders, and ensures timely deliveries. Riley recruits drivers, organizes schedules, and manages customer communication. Morgan monitors inventory, adjusts delivery zones, and coordinates with suppliers. Riley ensures proper documentation, resolves issues, and maintains driver performance. Together, they analyze customer feedback, refine processes, and optimize delivery efficiency, to improve service and reduce delivery times."
#         ]
#     }
# ]
# Extracted scenarios saved to: scenarios.json

# %%
import json

with open("scenarios.json", "r", encoding="utf-8") as file:
    data = json.load(file)

data  # Displays JSON content
# Out:
# [{'number': 1,
#   'title': 'Running a hairdressing salon',
#   'description': ['Avery and Jordan are running a hairdressing salon together. Both take on key roles—Avery focusing on styling hair and Jordan managing operations. Avery consults clients, cuts and colors hair, and stays updated on trends. Jordan schedules appointments, orders supplies, and ensures a smooth workflow. Avery experiments with techniques, recommends treatments, and personalizes styles. Jordan handles customer service, manages finances, and promotes the salon. They collaborate on marketing, refine services based on feedback, and work together to create a welcoming atmosphere.']},
#  {'number': 2,
#   'title': 'Startup Leadership',
#   'description': ["Jordan and Taylor co-found a tech startup. Both are involved in the company's growth—Jordan focuses on securing funding, managing investor relations, overseeing marketing, and tracking expenses, while also driving business development. Taylor leads software development, tests prototypes, ensures product quality, and maintains workflow efficiency. Their roles are distinct but complementary, and they take a collaborative approach to strategic decision-making. Despite their different strategies, they work together to set goals for the company’s growth and success, maintaining open communication and mutual support to ensure their business thrives."]},
#  {'number': 3,
#   'title': 'Home renovation',
#   'description': ['Alex and Casey are renovating their home. Alex focuses on researching materials, comparing costs, sourcing supplies, and contacting contractors, while Casey handles logistics, supervises progress, schedules tasks, and ensures permits are in place. They take a collaborative approach to managing the renovation. Despite their different responsibilities, they work together to track expenses and stay on budget, setting shared goals to ensure the renovation is completed on time and within their financial plan. Through open communication and mutual support, they successfully navigate the challenges of home renovation.']},
#  {'number': 4,
#   'title': 'Academic Research',
#   'description': ['Quinn and Avery are conducting academic research, each bringing their expertise to different aspects of the project. Quinn focuses on data collection, designing surveys, running analyses, and interpreting results, while Avery refines the research methodology, organizes sources, writes reports, and formats findings. They take a collaborative approach to refining their work. Despite their different responsibilities, they coordinate closely on revisions and prepare presentations together, ensuring their research is well-structured and effectively communicated. Through open communication and shared dedication, they work toward producing high-quality academic work.']},
#  {'number': 5,
#   'title': 'Café Management',
#   'description': ['Sky and Devon run a café, each contributing their expertise to different aspects of the business. Sky focuses on financial management, staff scheduling, and coordinating with suppliers, ensuring smooth day-to-day operations. Devon oversees menu development, enhances the customer experience, and maintains quality control to uphold the café’s standards. They take a collaborative approach to business management. Despite their different responsibilities, they regularly discuss improvements and align their goals to create a welcoming, innovative, and successful café. They work together to sustain and grow their thriving business.']},
#  {'number': 6,
#   'title': 'Content creation partnership',
#   'description': ['Drew and Jordan work as independent creatives, each contributing their expertise to different aspects of their projects. Drew focuses on content creation, writing articles, developing marketing strategies, and managing client outreach, while Jordan specializes in visual design, editing graphics, and ensuring branding consistency. Despite their different responsibilities, they regularly review projects together, aligning their creative vision to produce cohesive and high-quality results. Through open communication and shared dedication, they successfully balance their skills to meet client needs and achieve their professional goals.']},
#  {'number': 7,
#   'title': 'Community Garden Management',
#   'description': ['River and Morgan run a community garden, each contributing to different aspects of its success. River focuses on outreach, organizing volunteers, coordinating educational workshops, and planning community events, while Morgan handles garden upkeep, maintaining irrigation systems, overseeing planting, and ensuring soil health. They collaborate to garden management. Despite their different responsibilities, they work together to plan sustainable initiatives, fostering a thriving and inclusive green space. They create a welcoming environment for the community to engage with nature and sustainable gardening practices.']},
#  {'number': 8,
#   'title': 'Nonprofit Management',
#   'description': ['Taylor and Alex manage a nonprofit, each bringing their expertise to different aspects of the organization. Taylor focuses on networking, securing funding, applying for grants, and building strategic partnerships, while Alex oversees operations by coordinating volunteers, organizing impactful events, and managing daily tasks. They take a collaborative approach to leadership. Despite their different responsibilities, they work together to set and achieve long-term goals, ensuring the nonprofit’s sustainability and lasting impact. Through open communication and shared dedication, they foster a well-organized and mission-driven organization that serves its community effectively.']},
#  {'number': 9,
#   'title': 'Band Leadership',
#   'description': ['Cameron and Riley play in a band, each taking on leadership roles in different aspects of its success. Cameron focuses on the musical side, writing original songs, scheduling rehearsals, and engaging with passionate fans, while Riley manages logistics by handling bookings, overseeing finances, and coordinating merchandise. Despite their different responsibilities, they take a collaborative approach on creative decisions, ensuring their music and brand evolve in alignment with their shared vision. Through open communication and mutual commitment, they balance artistic expression with the practical needs of their growing band.']},
#  {'number': 10,
#   'title': 'Road Trip Planning',
#   'description': ['Sam and Casey are planning a road trip, each taking on key responsibilities to ensure a smooth journey. Sam focuses on mapping scenic routes, researching destinations, booking accommodations, and checking travel conditions, while Casey manages supplies by organizing packing, maintaining the vehicle, and tracking expenses. Despite their different tasks, they take a collaborative approach to finalize plans, making adjustments as needed to create a well-organized and enjoyable experience. Through open communication and shared enthusiasm, they work together to make their adventure both seamless and unforgettable.']},
#  {'number': 11,
#   'title': 'Short Film Production',
#   'description': ['"Jordan Blake make a short film. Each contribute to different aspects of the project—Jordan focusing on direction and Blake on production. They take a collaborative approach to filmmaking process, with Jordan overseeing filming, working with talented actors, refining storytelling, exploring innovative techniques, making creative decisions, while Blake handling logistics, managing tight schedules, arranging necessary permits, securing locations, editing raw footage. They collaborate closely on the final cut, ensuring a cohesive and high-quality result through open communication, mutual trust, andclear goals."']},
#  {'number': 12,
#   'title': 'Marketing partnership',
#   'description': ['Alex and Quinn are launching a new product. Both focus on promotion—Alex on branding and Quinn on advertising. They take a collaborative approach, with Quinn focusing on data-driven campaign analysis and Alex exploring innovative creative engagement strategies. Quinn prefers traditional advertising metrics, while Alex enjoys experimenting with emerging social media trends. Despite their different strategies, they refine their marketing efforts together, ensuring a cohesive brand message, maintaining open communication, and driving success to achieve their shared goal of a highly successful product launch.']},
#  {'number': 13,
#   'title': 'Restaurant co-ownership',
#   'description': ['Sky and Taylor own a restaurant. Both take a collaborative approach to running the business—Sky focusing on operations and Taylor on food quality. Sky manages supplier relationships, staff scheduling, and overall efficiency, ensuring smooth daily operations. Taylor, on the other hand, curates the menu, oversees kitchen execution, and upholds culinary standards. Sky focuses on structured planning and logistics, while Taylor emphasizes creativity and consistency in the dining experience. They try to maintain open communication to regularly review finances, customer feedback, and operational performance together.']},
#  {'number': 14,
#   'title': 'Household maintenance',
#   'description': ['Jordan and Morgan share an apartment. They take a collaborative approach to maintaining their apartment, each focusing on specific tasks. Jordan handles the daily cleaning, including vacuuming, taking out the trash, and wiping down surfaces. Morgan, on the other hand, manages laundry, organizing the kitchen, and ensuring the bathroom is tidy. Jordan focuses on keeping the space neat, organized, and orderly, while Morgan ensures everything is in place and fresh. They communicate regularly to keep the apartment running efficiently and ensure no task is overlooked, fostering a harmonious living environment.']},
#  {'number': 15,
#   'title': 'Graphic design studio co-ownership',
#   'description': ["Jordan and Casey co-own a graphic design studio. Both take a collaborative approach to running the business—Jordan focusing on client relations and Casey on creative direction. Jordan manages client communications, handles project timelines, and ensures the smooth flow of deliverables, keeps track of the studio’s contracts and client satisfaction. Casey, on the other hand, leads the design process, curates the studio's visual identity, and refines the creative output. Together, they regularly review project progress, budget management, and client feedback to ensure continuous success and growth."]},
#  {'number': 16,
#   'title': 'Trip organizing',
#   'description': ['Casey and Avery are organizing a trip, each focusing on different aspects. Casey handles travel logistics, comparing flight options, booking hotels, and managing documents. Avery plans activities, researching local attractions, arranging sightseeing, and coordinating with guides. While Casey ensures smooth transportation and accommodations, Avery creates a memorable experience through carefully planned excursions and dining recommendations. They maintain open communication, adjusting plans as needed, reviewing the budget, and ensuring every detail aligns to create a seamless and enjoyable trip.']},
#  {'number': 17,
#   'title': 'Meal cooking',
#   'description': ['Quinn and Drew cook at home. Both enjoy different roles—Quinn focusing on meal planning and Drew on cooking. Quinn selects recipes, creates grocery lists, and ensures dietary needs are met, while Drew handles meal preparation, experiments with new dishes, and manages leftovers. Their approaches to cooking differ—Quinn prefers structured meal plans, while Drew enjoys creating in the kitchen. Despite their different methods, they collaborate on meal choices and share the workload, swapping roles on weekends to keep things balanced, efficient, and enjoyable..']},
#  {'number': 18,
#   'title': 'Library collaboration',
#   'description': ['Morgan and Devon work in a library. They take a collaborative approach to handling responsibilities—Morgan focusing on digitizing records and Devon on organizing physical books. Morgan scans and categorizes historical documents, converting them into digital formats, while Devon arranges books on shelves, labels sections, and updates the library catalog to ensure everything is easy to find. They collaborate closely, ensuring that both the digital and physical collections are accessible, well-maintained, and properly organized. They meet regularly to discuss improvements, share innovative ideas, and adjust workflows for maximum efficiency.']},
#  {'number': 19,
#   'title': 'Workout partnership',
#   'description': ['Sky and Blake are workout partners. Both keep an eye on fitness goals—Sky focusing on endurance and Blake on strength. Sky leads intense cardio sessions, tracks running progress, and monitors stamina levels to ensure improvement. Blake, on the other hand, supervises weightlifting routines, and plans strength-building exercises to target specific muscle groups. They adjust their workouts as needed, based on their individual progress, ensuring each session is effective and challenging. Together, they maintain open communication to balance their training, pushing each other to reach their ultimate fitness goals.']},
#  {'number': 20,
#   'title': 'E-commerce partnership',
#   'description': ['Jordan and Casey run an e-commerce store. Both manage key operations—Jordan focusing on sales and Casey overseeing logistics. Jordan updates product listings, writes engaging descriptions, and communicates with customers to address inquiries and feedback. Casey, on the other hand, handles packing orders, arranging shipping, and tracking deliveries to ensure everything reaches customers on time. They analyze sales trends together, making data-driven decisions to optimize inventory and improve customer satisfaction. Regularly reviewing performance helps them adjust strategies and streamline operations for growth.']},
#  {'number': 21,
#   'title': 'Event planning',
#   'description': ['Avery and Taylor organize events. They take a collaborative approach in organizing events and split responsibilities—Avery focusing on logistics and Taylor handling promotions. Avery books venues, arranges catering, and creates detailed timelines to ensure the event runs smoothly. Taylor designs eye-catching invitations, markets the event across different platforms, and manages guest lists to ensure the right people are invited. After each event, they review feedback together to identify areas for improvement, ensuring their future events are even more successful, well-coordinated, and impactful.']},
#  {'number': 22,
#   'title': 'Pet care',
#   'description': ['Jordan and Quinn have a pet and share responsibilities to ensure its well-being—Jordan focusing on feeding and health, while Quinn manages exercise and engagement. Jordan prepares nutritious meals, tracks the pet’s diet, and schedules regular vet visits to monitor overall health. Quinn takes the pet for daily walks, engages in interactive playtime, and reinforces positive training routines for consistency. They communicate regularly, discuss behavioral changes or concerns, and adjust their care routine as needed to provide the best possible life for their pet.']},
#  {'number': 23,
#   'title': 'Leading a community clean up',
#   'description': ['Casey and Morgan lead a community cleanup, each playing a vital role in its success—with Casey focusing on volunteer coordination and Morgan handling logistics. Casey recruits helpers, spreads awareness through promotions, and tracks progress to keep participants engaged. Morgan gathers necessary supplies, arranges waste disposal, and assigns tasks to ensure efficiency. While Casey fosters community involvement, Morgan ensures operations run smoothly. After each event, they review outcomes, discuss improvements, and plan future initiatives mutually to maximize their impact.']},
#  {'number': 24,
#   'title': 'Retail store management',
#   'description': ['Blake and Sky work in a store, each focusing on key aspects—Blake handling operations and Sky handling customer service. Blake monitors inventory levels, sets competitive pricing, and ensures transactions are efficient and accurate. Sky interacts with customers, provides assistance, resolves complaints, and enhances the overall shopping experience. While Blake keeps the backend organized, Sky ensures the storefront remains welcoming and engaging. They regularly analyse sales trends together, adjusting strategies to improve efficiency, customer satisfaction, and overall performance.']},
#  {'number': 25,
#   'title': 'Moving to a new place',
#   'description': ['Riley and Drew are moving to a new place, each taking on specific responsibilities—Riley organizing packing and Drew managing transportation. Riley categorizes items, sorts through belongings to donate unused things, and secures boxes to ensure everything is neatly packed. Drew rents a truck, coordinates timing to ensure a smooth move, and carefully handles items to prevent damage. Once the move is complete, they unpack together, setting up their new home efficiently and ensuring everything has its place. They also clean the space, organize utilities, and finalize any outstanding tasks.']},
#  {'number': 26,
#   'title': 'Language Learning partners',
#   'description': ['Taylor and Cameron are learning a new language, each using a different approach—Taylor focusing on speaking and Cameron on writing. Taylor practices conversations, listens to native speakers, and memorizes useful phrases to improve fluency. Cameron studies grammar rules, completes writing exercises, and expands their vocabulary for better sentence structure. They support each other’s progress by testing one another weekly, combining their strengths to develop well-rounded language skills. Their collaboration keeps them motivated and helps them learn more effectively, track milestones, and refine their pronunciation.']},
#  {'number': 27,
#   'title': 'eSport partnership',
#   'description': ['Devon and Morgan compete in eSports, each playing a crucial role in their team’s success—Devon focusing on strategy and Morgan on practice management. Devon studies opponents, refines game plans, and leads tactical discussions to improve gameplay. Morgan organizes practice schedules, reviews performance metrics, and keeps team morale high to maintain focus and motivation. While Devon ensures smart in-game decisions, Morgan optimizes preparation and teamwork. They analyze match results together, adjusting tactics to stay competitive and make sure they are improving.']},
#  {'number': 28,
#   'title': 'Speech preparation',
#   'description': ['Jordan and Sky are preparing a speech for their project, each contributing to a different aspect—Jordan focusing on delivery and Sky on content structure. Jordan practices tone, refines body language, and improves voice projection to enhance audience engagement. Sky organizes key points, ensures clarity, and adjusts timing for a smooth, effective flow. While Jordan brings confidence and presence to the speech, Sky fine-tunes the message for maximum impact. They rehearse together, providing constructive feedback and making necessary adjustments until they feel fully prepared and polished.']},
#  {'number': 29,
#   'title': 'Home office set up',
#   'description': ['Quinn and Avery are setting up a home office, each focusing on different aspects—Quinn designing the space and Avery managing technology. Quinn arranges furniture, optimizes lighting, and decorates to create a comfortable and inspiring workspace. Avery sets up computers, installs essential software, configures networks, and ensures internet reliability for seamless connectivity. While Quinn enhances organization and aesthetics, Avery focuses on functionality, technical efficiency, and system integration. They collaborate to adjust the layout as needed, ensuring the space is both productive and visually appealing.']},
#  {'number': 30,
#   'title': 'Co-writing a book',
#   'description': ['Casey and Drew are writing a book, each contributing their strengths—Casey focusing on story development and Drew on editing. Casey drafts chapters, develops characters, structures the plot, and outlines key events to create a compelling narrative. Drew refines grammar, ensures consistency, polishes the language, checks for errors, and improves sentence structure to enhance clarity and flow. While Casey brings creativity and storytelling, Drew provides precision and refinement. They collaborate in reviewing each draft, making revisions, and perfecting details until they are fully satisfied with the final manuscript.']},
#  {'number': 31,
#   'title': 'Shelter co-workers',
#   'description': ['Taylor and Riley help at a shelter, each focusing on different responsibilities—Taylor organizing resources and Riley working directly with residents. Taylor sorts donations, manages supplies, and coordinates volunteer efforts to ensure operations run smoothly. Riley distributes meals, listens to residents’ concerns, and assists with paperwork to provide necessary support. While Taylor maintains structure and organization, Riley offers hands-on assistance and emotional support. After each shift, they debrief together, discussing challenges, sharing insights, and finding ways to improve their work.']},
#  {'number': 32,
#   'title': 'car ownership',
#   'description': ['Blake and Cameron take care of their car, each focusing on different aspects—Blake handling inspections and Cameron managing cleanliness. Blake checks oil levels, monitors tire pressure, schedules regular servicing, and tracks repairs to ensure the car runs smoothly. Cameron takes care of cleaning the interior, washing the exterior, organizing the trunk, and vacuuming the seats to keep everything tidy. They work together to maintain maintenance records, ensuring their car remains in top condition and stays reliable for every journey.']},
#  {'number': 33,
#   'title': 'Planning a hiking trip',
#   'description': ['Jordan and Devon plan a hiking trip, each taking charge of different tasks—Jordan researching trails and Devon organizing gear. Jordan checks trail difficulty, reviews weather forecasts, ensures all safety guidelines are followed, and identifies potential hazards for a secure experience. Devon packs essential equipment, arranges food, makes sure first-aid supplies are ready, and coordinates with local guides in case of emergencies. They communicate about potential risks, review emergency plans, and ensure everything is prepared for a safe and enjoyable adventure in the great outdoors.']},
#  {'number': 34,
#   'title': 'science project partnership',
#   'description': ['Morgan and Sky are working on a science project, each focusing on key tasks—Morgan conducting experiments and Sky documenting the entire process. Morgan sets up tests, adjusts variables, records results, analyzes data, and monitors outcomes to gather valuable insights. Sky writes detailed reports, prepares visuals like charts or graphs, structures the final presentation, and organizes findings to ensure clear communication. They collaborate by practicing their explanation together, refining how they present the project to ensure it’s informative, engaging, and accurate for their audience.']},
#  {'number': 35,
#   'title': 'Redecorating an apartment',
#   'description': ['Casey and Avery are redecorating their apartment, each taking responsibility for different areas—Casey focusing on choosing furniture and Avery managing the layout. Casey selects colors, buys decorations, matches themes, researches trends, and shops for accessories to create a unified aesthetic throughout the space. Avery arranges the furniture, maximizes available space, ensures the layout is both functional and comfortable, and coordinates with contractors for any renovations. Together, they finalize decisions based on comfort and style, making sure every element complements each other, so that the space is both beautiful and practical for everyday living.']},
#  {'number': 36,
#   'title': 'Hosting a game night',
#   'description': ['Quinn and Taylor host a game night, each preparing different aspects—Quinn setting up games and Taylor handling food and drinks. Quinn explains the rules, organizes teams, ensures fairness during gameplay, monitors time, and adjusts difficulty levels to create an enjoyable and competitive atmosphere. Taylor prepares snacks, manages drinks, sets the right ambiance with music and lighting, and coordinates with guests for dietary preferences . Throughout the night, they keep track of everyone’s enjoyment, making adjustments as needed to ensure a memorable experience for all guests.']},
#  {'number': 37,
#   'title': 'Art show partnership',
#   'description': ["Blake and Riley organize an art show, each overseeing different aspects—Blake managing logistics and Riley curating the displays. Blake handles the venue booking, schedules artists, promotes the event to attract visitors, and coordinates transportation for artwork. Riley arranges the artwork, sets the themes for each section, and ensures the proper lighting to highlight the pieces. They collaborate in reviewing the final setup together to ensure everything aligns perfectly. Their combined efforts create a visually stunning and well-organized art show that engages attendees and showcases the artists' work beautifully."]},
#  {'number': 38,
#   'title': 'Hosting a podcast',
#   'description': ['Morgan and Jordan host a podcast, each contributing differently—Morgan managing topics and Jordan handling editing. Morgan researches potential guests, prepares scripts, leads discussions, organizes interview schedules, and curates content. Jordan records the sessions, edits the audio for clarity and flow, uploads the episodes, monitors sound quality, and formats the content for different platforms. Together, they review feedback from their audience, discuss areas for improvement, adjust future content, and brainstorm new ideas. Their teamwork ensures a polished and engaging podcast experience for their listeners.']},
#  {'number': 39,
#   'title': 'Running a food drive',
#   'description': ['Sky and Casey run a food drive, each taking charge of different responsibilities—Sky gathering donations and Casey overseeing distribution. Sky contacts donors, sets up collection points, tracks contributions, manages inventory, and coordinates with businesses for support. Casey organizes the packing of food, coordinates volunteers, manages logistics for transportation, ensures timely delivery to those in need, and monitors the process for efficiency. After the drive, they evaluate its success based on the impact it had on the community, discuss areas for improvement, and plan future initiatives to help more people.']},
#  {'number': 40,
#   'title': 'Brewing partnership',
#   'description': ['Cameron and Drew are brewing homemade drinks, each with a specific role—Cameron focusing on flavors and Drew managing fermentation. Cameron experiments with ingredients, adjusts recipes to improve taste, tests each batch for balance, records results, and makes notes for future experiments. Drew tracks brewing times, ensures the process maintains cleanliness, sanitizes equipment, bottles the final product, and monitors storage conditions. Together, they refine their brewing methods based on the results of each batch, making adjustments to improve the quality and taste of their homemade drinks.']},
#  {'number': 41,
#   'title': 'Organizing a charity event',
#   'description': ['Avery and Riley are organizing a charity event, each contributing in different ways—Avery managing outreach and Riley coordinating logistics. Avery contacts potential donors, spreads awareness through social media, promotes the fundraiser, and builds partnerships to encourage participation. Riley handles venue bookings, arranges event activities, tracks donations, and manages volunteer schedules to ensure everything runs smoothly. After the event, they evaluate its success together, discussing the impact of their efforts, analyzing feedback, and planning improvements for future events to further support the cause.']},
#  {'number': 42,
#   'title': 'Bakery co-ownership',
#   'description': ['Taylor and Morgan run a small bakery, each focusing on different areas to ensure success—Taylor handling sales and Morgan perfecting recipes. Taylor manages customer orders, oversees service, sets pricing, tracks inventory, and organizes promotions to maintain business. Morgan experiments with ingredients, bakes a variety of goods, ensures each item meets quality standards, and monitors baking times for consistency. They regularly review customer feedback together to refine their offerings, introducing new products and making adjustments to improve taste and presentation.']},
#  {'number': 43,
#   'title': 'Dog training partnership',
#   'description': ['Blake and Casey train their dog, each taking responsibility for different aspects—Blake teaching tricks and Casey reinforcing discipline. Blake introduces new commands, rewards progress, ensures consistency, and tracks the dog’s reactions during training. Casey focuses on correcting bad habits, tracking improvements, and managing the training schedule to ensure steady progress. Together, they assess the results of their efforts, discussing what’s working well and making adjustments as needed. Their teamwork helps the dog learn effectively, promoting good behavior and a strong bond with its owners.']},
#  {'number': 44,
#   'title': 'Project leadership',
#   'description': ['Jordan and Sky lead a work project, each handling different areas—Jordan managing deadlines and Sky refining strategy. Jordan assigns tasks to the team, sets clear milestones, and regularly checks progress to ensure everything stays on track. Sky organizes brainstorming sessions, ensures team efficiency, and monitors workflow to optimize productivity. They collaborate closely throughout the project, regularly reviewing the work, making adjustments when needed, and combining their efforts to report findings together, ensuring the project is completed successfully and on time.']},
#  {'number': 45,
#   'title': 'Backyard redesign',
#   'description': ['Cameron and Quinn redesign their backyard, each taking on different tasks—Cameron focusing on planning and Quinn handling maintenance. Cameron selects plants, designs layouts, coordinates purchases, and manages the budget to create a beautiful and functional space. Quinn takes responsibility for digging, planting, regularly watering the garden, and maintaining soil health to ensure everything thrives. Together, they adjust designs based on the results, observing how plants grow and making changes to improve the overall aesthetic and health of the garden. Their collaboration brings the backyard vision to life.']},
#  {'number': 46,
#   'title': 'food contest',
#   'description': ['Morgan and Drew enter a food contest, each contributing in different ways—Morgan focusing on creativity and Drew managing execution. Morgan selects unique recipes, experiments with different flavors, tests the presentation, and designs the overall concept to ensure it stands out. Drew handles timing, organizes ingredients, perfects cooking techniques, tracks progress, and ensures consistency in the dish’s preparation to achieve the best possible results. Together, they refine their dish before submission, making adjustments as needed to ensure their creation is both innovative and well-executed, ultimately enhancing their chances of success in the competition.']},
#  {'number': 47,
#   'title': 'Conducting an experiment at home',
#   'description': ['Avery and Riley conduct a home experiment, each playing an important role—Avery designing the procedures while Riley recording the results. Avery selects hypotheses, sets up tests, manages variables, monitors progress, adjusting the experiment’s direction based on observations. Riley logs the data, analyzes patterns, summarizes findings, ensuring consistency in the data collection process. Together, they regularly assess the experiment’s progress, adjusting their approach based on outcomes. Their collaboration ensures that the experiment is carried out thoroughly, with precise data collection and analysis to yield meaningful results.']},
#  {'number': 48,
#   'title': 'Thrift adventure',
#   'description': ['Taylor and Sky are going thrifting, each focusing on different aspects—Taylor searching for fashion items and Sky looking for home décor. Taylor looks for vintage clothing, checks the quality, styles outfits, and selects pieces that align with current trends. Sky finds home décor, tests functionality, compares prices, and organizes items to ensure they’re getting the best deals. After browsing, they come together to make final choices, sharing thoughts on what works best for their needs. Their collaboration ensures they find the perfect pieces for both fashion and home.']},
#  {'number': 49,
#   'title': 'board game design',
#   'description': ['Blake and Cameron are designing a board game, each taking on distinct responsibilities—Blake creating the mechanics and Cameron refining the aesthetics. Blake develops the rulebook, constructs prototypes, evaluates player interactions, modifies game flow for engagement, and balances difficulty levels to ensure fairness. Cameron focuses on designing artwork, selecting components, coordinating production, finalizing packaging, and formatting the board for a visually appealing experience. They collaborate regularly to test the game with friends to gather feedback, making final adjustments before releasing it to the public and ensuring it is both enjoyable and well-designed.']},
#  {'number': 50,
#   'title': 'Furniture Building',
#   'description': ['Casey and Morgan build furniture; each try to contribute to different parts of the process—Casey focusing on design and Morgan on assembly. Casey drafts blueprints, calculates measurements, sources materials, tests structural integrity, and refines aesthetic details to ensure the design is functional and stylish. Morgan cuts the wood, fastens components, reinforces joints, smooths surfaces, and ensures everything is stable and secure. After assembly, they check the durability of the finished product collaboratively and make sure it is built to last. Together, they complete each piece with attention to detail and quality craftsmanship.']},
#  {'number': 51,
#   'title': 'Social media partnership',
#   'description': ['" Drew and Quinn run a social media page, each handling distinct tasks—Drew creating content, Quinn tracking engagement. Drew writes creative captions, edits videos for clarity, schedules posts to maximize reach. Quinn analyzes metrics, monitors reach, interacts with followers, refines strategy based on data insights. They frequently review analytics together, adjusting approach to improve visibility, maintain audience interest. Their teamwork ensures a dynamic presence that adapts to evolving trends with unwavering, consistent determination."']},
#  {'number': 52,
#   'title': 'Organizing a local festival',
#   'description': ['Jordan and Avery organize a local festival, each taking charge in different ways—Jordan handling logistics, Avery promoting the event. Jordan secures vendors, arranges permits, manages schedules to ensure everything runs smoothly, coordinating with various teams. Meanwhile, Avery advertises the festival, engages with media outlets, attracts visitors through targeted campaigns and community outreach. After the event, they measure success by reviewing attendance, feedback, overall impact, using results to plan future improvements. They also evaluate key partnerships, sponsorship growth.']},
#  {'number': 53,
#   'title': 'Running a photography business',
#   'description': ['Taylor and Casey run a photography business, each playing a key role—Taylor handling shoots and Casey managing the editing process. Taylor directs clients, sets up lighting scenes, and takes high-quality photos to capture the perfect moments. Casey retouches images, selects the final shots that best represent the session, and prepares albums that showcase their work. They organize bookings, review customer feedback together to identify areas of improvement, and finalize contracts, ensuring each project leaves clients satisfied and eager to come back for more memorable photoshoots.']},
#  {'number': 54,
#   'title': 'Book collection project',
#   'description': ['Blake and Riley arrange their book collection, each taking charge of distinct tasks—Blake categorizing and Riley designing the layout. Blake carefully sorts books by genre, labels sections clearly, and creates a comprehensive catalog to organize the collection. Meanwhile, Riley arranges shelves thoughtfully, decorates the space to enhance visual appeal, and ensures accessibility for all readers. Together, they review the system, discussing improvements and making adjustments to optimize organization. Their collaborative efforts result in a functional and aesthetically pleasing book collection for future enjoyment.']},
#  {'number': 55,
#   'title': 'stand up comedy collaboration',
#   'description': ['Morgan and Sky try stand-up comedy, each playing a distinct role—Morgan writing jokes and Sky refining delivery. Morgan brainstorms themes, tests material, and carefully structures sets to engage the audience. Sky practices timing, adjusts tone, and interacts with the crowd during performances to capture reactions. They review recordings together, analyze responses, and refine scripts, discussing what works best and making adjustments based on audience feedback. Their collaboration enables them to continuously improve, ensuring each performance is dynamic, engaging, and thoroughly entertaining for all who attend with great success.']},
#  {'number': 56,
#   'title': 'Blog partnership',
#   'description': ["Drew and Jordan run a blog, each contributing unique skills—Drew focusing on writing articles while Jordan manages visuals. Drew researches engaging topics, drafts posts, and ensures readability. Meanwhile, Jordan takes original photos, designs layouts, and enhances presentation to capture readers' attention. Together, they revise every piece before posting, ensuring quality content and visual harmony. Their teamwork creates a dynamic blog that informs, entertains, and continuously evolves to meet audience needs. Their passion, creativity, and dedication drive success."]},
#  {'number': 57,
#   'title': 'Educational course creation',
#   'description': ['Avery and Quinn are creating an educational course; they share duties to blend content creation with lesson structuring. Avery writes materials, records engaging videos, and practical examples to illustrate key concepts. Quinn organizes course modules, builds quizzes, and ensures lessons remain engaging and accessible for students. Together, they regularly review and refine the curriculum based on student feedback, enhancing content quality and instructional design to maximize learning outcomes and foster a dynamic, effective educational experience.']},
#  {'number': 58,
#   'title': 'Scape room challenge',
#   'description': ['Cameron and Casey attempt an escape room challenge, each approaching with a distinct strategy. Cameron focuses on solving puzzles by deciphering intricate clues, testing creative ideas, and connecting patterns hidden throughout the room. Meanwhile, Casey manages time efficiently by tracking progress, staying organized, and setting clear priorities to ensure they do not fall behind. Together, they communicate constantly, adjusting their tactics and pooling their strengths to escape before time runs out. Their excellent teamwork proves essential for overcoming every obstacle successfully.']},
#  {'number': 59,
#   'title': 'Organizing a charity concert',
#   'description': ['Taylor and Morgan are organizing a charity concert, each contributing their expertise to ensure a successful event. Taylor manages the artistic side by scouting talented performers, scheduling rehearsals, and coordinating seamless on-stage execution. Morgan handles logistics by securing the perfect venue, arranging sound and lighting, and overseeing ticket sales and donations. Together, they diligently track progress and adjust plans based on valuable audience feedback, working collaboratively to create an engaging event that raises crucial funds for a worthy cause and strengthens community spirit.']},
#  {'number': 60,
#   'title': 'Urban gardening project',
#   'description': ["Blake and Sky are starting an urban garden, each contributing to distinct skills to ensure a thriving green space. Blake takes charge of planting, selecting crops, preparing the soil, and watering to foster healthy growth. Meanwhile, Sky handles logistics by finding an ideal space, securing permits, and organizing supplies to support the garden's needs. Together, they monitor progress and evaluate harvest results, discussing improvements and celebrating successes along the way. Their teamwork transforms a simple plot into a vibrant urban oasis."]},
#  {'number': 61,
#   'title': 'Documenting travels',
#   'description': ['Riley and Quinn document their travels, each bringing a unique perspective to their shared adventures. Riley focuses on writing, journaling experiences in detail, researching destinations for deeper context, and crafting engaging stories to share insights. Quinn captures the visual essence of their journey by taking photographs, editing footage, and curating stunning albums that complement Riley’s narratives. Together, they publish their stories, blending words and imagery to create immersive travel content that inspires others and preserves their memories in a meaningful way.']},
#  {'number': 62,
#   'title': 'Music co-production',
#   'description': ['Drew and Cameron produce songs, each contributing their unique expertise to create music. Drew focuses on writing melodies, playing instruments, and structuring tracks to establish the foundation. Meanwhile, Cameron handles mixing, adjusting sound levels, editing recordings, and enhancing overall audio quality for a professional finish. Together, they refine each piece, ensuring a balanced blend of creativity and technical precision. Before release, they review every detail, making final adjustments to their sound and deliver an engaging, memorable listening experience.']},
#  {'number': 63,
#   'title': 'Camping adventure',
#   'description': ['Casey and Avery go camping, each taking on essential responsibilities to ensure a smooth outdoor experience. Casey focuses on shelter, gathering firewood, setting up tents, and ensuring their campsite is safe and secure. Meanwhile, Avery manages food, cooking meals, storing supplies properly, and keeping a close eye on local wildlife. Together, they check weather conditions before each trip, planning routes, and adjust their setup based on the environment. Their teamwork and communication allow them to enjoy nature while staying prepared and comfortable..']},
#  {'number': 64,
#   'title': 'Stage production',
#   'description': ['Morgan and Sky direct a play, working to bring their vision to life. Morgan focuses on performances, coaching actors, refining dialogue delivery, and ensuring emotional depth. Sky oversees production, designing staging, coordinating costumes, and managing lighting. They collaborate on script development, organize rehearsals, and adjust scenes for maximum impact. Together, they ensure seamless transitions, guide the cast and crew, and fine-tune every detail. Their combined efforts create a polished, engaging production that captivates audiences and brings the story to life.']},
#  {'number': 65,
#   'title': 'Jewellery creation',
#   'description': ['Taylor and Jordan create handmade jewellery, each focusing on key aspects of the process. Taylor designs the pieces, sketching ideas, selecting high-quality materials, and refining concepts to ensure a unique style. Jordan handles the assembly, carefully crafting each piece, ensuring its durability, and polishing the final product to perfection. Together, they coordinate the pricing of their jewellery, oversee the preparation for sale, and manage customer relations, while refining their marketing strategies. Their combined skills and dedication result in beautiful, high-quality pieces that reflect both creativity and craftsmanship.']},
#  {'number': 66,
#   'title': 'Furniture revamp',
#   'description': ['Cameron and Quinn restore old furniture, each focusing on a specific role to bring pieces back to life. Cameron strips paint, sands wood, removes stains, and repairs any damage to prepare the surface for refinishing. Quinn then applies coatings, polishes finishes, and ensures the longevity of each piece through careful preservation and protective treatments. Together, they check the final results, ensuring the furniture is in excellent condition before selling or displaying. Their combined efforts transform worn-out items into beautifully restored, functional, and high-quality works of art.']},
#  {'number': 67,
#   'title': 'Comic creation',
#   'description': ['Avery and Morgan create comics, each focusing on different aspects of the process. Avery writes the story, developing plots, crafting dialogue, and structuring the panels for a smooth narrative. Morgan brings the story to life through illustrations, sketching characters, inking pages, and adding color to scenes. They work closely to finalize each issue, ensuring the artwork and writing complement each other perfectly. Together, they share responsibility for meeting deadlines, creating a comic that blends compelling storytelling with visually engaging artwork, capturing the attention of readers.']},
#  {'number': 68,
#   'title': 'running a community paper',
#   'description': ['Sky and Casey start a community paper, each taking on key responsibilities. Sky focuses on writing the news, researching stories, interviewing sources, and drafting articles to provide engaging and informative content. Casey handles the layout, formatting pages, selecting images, and managing the printing process to ensure the paper looks professional and visually appealing. Together, they coordinate, oversee distribution, and track feedback to improve each issue, making sure it reaches their audience with up-to-date, relevant information while maintaining a polished, cohesive design.']},
#  {'number': 69,
#   'title': 'Launching a coffee roasting company',
#   'description': ['Jordan and Avery launch a coffee roasting company. Both work full-time in their respective roles—Jordan meticulously sources premium beans and negotiates with global suppliers, while Avery expertly manages the roasting process and experiments with temperatures and flavors. They collaborate at every stage, combining creative sourcing with innovative roasting techniques. Their joint efforts result in carefully refined blends that cater to diverse tastes, clearly demonstrating their commitment to quality, innovation, and shared vision in every cup of coffee they produce for true coffee enthusiasts.']},
#  {'number': 70,
#   'title': 'Launching a local podcast',
#   'description': ['Casey and Riley launch a local podcast, each focusing on different aspects of the production. Casey handles the interviews, researching topics, inviting guests, and leading discussions to ensure engaging content. Riley manages production, recording sessions, editing audio, and uploading episodes to make sure a smooth delivery. Together, they track audience engagement, analyse feedback, and adjust future content to improve listener experience. Their collaborative efforts bring dynamic, informative, and entertaining episodes to their growing podcast audience.']},
#  {'number': 71,
#   'title': 'Household budget',
# ...
#  {'number': 78,
#   'title': 'Photography project',
#   'description': ['Morgan and Casey explore abandoned places for photography, each handling different aspects. Morgan focuses on planning, researching locations, ensuring safety, and mapping routes. Casey focuses on capturing stunning shots, adjusting camera settings, finding the perfect angles, and editing photos to enhance the atmosphere. Together, they ensure the project runs smoothly, coordinating their efforts to capture the essence of each location. Afterward, they compile their work into a gallery, showcasing their unique perspective of the forgotten spaces. Their collaboration results in a compelling visual story of exploration and creativity.']},
#  {'number': 79,
#   'title': 'Designing a mini-golf course',
#   'description': ['Sky and Taylor are designing a mini-golf course. Both contribute to different aspects—Sky creating obstacles and Taylor managing logistics. Sky designs challenging holes, tests layouts, and adds creative themes. Taylor arranges course setup, coordinates schedules, handles marketing, and manages budgeting. Sky ensures the obstacles are fun and engaging, while Taylor makes sure the experience runs smoothly for players. They review feedback from visitors to refine and improve the course, making adjustments to both the design and logistics to ensure a memorable and well-organized experience for all.']},
#  {'number': 80,
#   'title': 'Maintaining an urban beehive',
#   'description': ['Jordan and Drew maintain an urban beehive. Both have duties—Jordan monitoring the hive and Drew harvesting honey. Jordan inspects colony health, checks for pests, manages hive expansion, and tracks bee activity. Drew extracts honey, filters wax, and packages products for sale. Jordan ensures the bees have a sustainable environment, while Drew maintains equipment and storage. They collaborate on seasonal management, adjusting care based on weather, nectar flow, and hive conditions. Together, they educate the community on pollination, environmental responsibility, and the importance of urban beekeeping.']},
#  {'number': 81,
#   'title': 'Organizing a coastal cleanup',
#   'description': ['Avery and Riley organize a coastal cleanup. Both take roles—Avery coordinating volunteers and Riley handling logistics. Avery promotes the event, gathers sponsors, and tracks participation numbers. Riley distributes cleanup tools, sorts collected waste, and ensures proper recycling and disposal. Avery communicates with local organizations to gain support, while Riley arranges transportation for debris removal. They document progress, analyze collected data, and report results to the community. Together, they work to raise awareness and enhance environmental conservation efforts along the coastline.']},
#  {'number': 82,
#   'title': 'Home business',
#   'description': ['Blake and Quinn create organic soaps. Both share tasks—Blake experimenting with formulas and Quinn handling packaging. Blake selects natural ingredients, tests scent combinations, and refines recipes for quality. Quinn designs labels, wraps bars, and creates appealing product displays. Blake researches skin benefits and ensures sustainability, while Quinn manages branding and promotions. They collaborate on pricing, production efficiency, and expanding their product line. Together, they track customer feedback and adjust formulas or designs to meet consumer preferences and market demand.']},
#  {'number': 83,
#   'title': 'Organizing a film festival',
#   'description': ['Cameron and Casey are organizing a film festival. Both contribute—Cameron curating films and Casey managing event logistics. Cameron selects movies, researches directors, and arranges Q&A sessions. Casey secures venues, coordinates screening schedules, and oversees ticket sales. Cameron ensures a diverse lineup, balancing genres and themes, while Casey handles permits, seating, and technical setups. They collaborate on marketing, reaching out to press and engaging audiences effectively. After the event, they gather feedback, analyze attendance, and discuss potential improvements for future festivals.']},
#  {'number': 84,
#   'title': 'Fixing old electronics',
#   'description': ['Morgan and Sky fix old electronics. Both take charge—Morgan diagnosing issues and Sky handling repairs. Morgan researches common problems, tests circuits, and sources replacement parts. Sky disassembles devices, replaces faulty components, and reassembles gadgets. Morgan ensures compatibility, troubleshoots errors, and fine-tunes performance. Sky cleans connections, checks wiring, and optimizes durability. They document fixes, share solutions, and improve efficiency over time. Before finalizing, they conduct thorough functionality tests to confirm proper operation and ensure reliability for long-term use.']},
#  {'number': 85,
#   'title': 'Fashion brand co-ownership',
#   'description': ['Taylor and Jordan are launching an eco-friendly fashion brand. Both have roles—Taylor designing apparel and Jordan sourcing materials. Taylor sketches outfits, chooses fabrics, and ensures comfort and style. Jordan researches sustainable materials, negotiates with ethical suppliers, and oversees production costs. Taylor focuses on innovative designs, keeping environmental impact in mind. Jordan ensures the brand’s supply chain supports fair trade practices and minimal waste. They collaborate to create a brand that champions responsible consumption, promoting eco-conscious choices in the fashion industry.']},
#  {'number': 86,
#   'title': 'Running a bookstore',
#   'description': ['Drew and Avery run a bookstore. Both divide tasks—Drew handling inventory and Avery engaging with customers. Drew orders books, tracks stock, manages suppliers, and ensures the bookstore is always stocked. Avery arranges displays, hosts events like author readings, and offers personalized book recommendations to customers. Drew monitors trends and adapts inventory accordingly. Avery builds strong customer relationships, creating a welcoming atmosphere. Together, they ensure to stay current with literary trends and deliver a great customer experience.']},
#  {'number': 87,
#   'title': 'Animal rescue',
#   'description': ['Blake and Casey help at an animal rescue. Both contribute—Blake assisting with adoptions and Casey caring for animals. Blake processes adoption applications, conducts interviews with potential adopters, and handles the necessary paperwork. Casey is responsible for feeding, grooming, and socializing the animals, ensuring they are well cared for and healthy. Together, they create a seamless adoption process, managing records, matching pets with loving homes. They work closely to ensure the animals’ needs are met while providing adopters with the support, education, and guidance they need throughout the process.']},
#  {'number': 88,
#   'title': 'Hosting a cooking class',
#   'description': ['Morgan and Quinn host a cooking class. Both take charge based on their experties—Morgan planning recipes and Quinn managing the class. Morgan selects dishes, researches techniques, and prepares demonstrations. Quinn organizes the class schedule, sets up equipment, and ensures participants stay on track. Morgan provides guidance, answers questions, and helps with cooking tips. Quinn assists with hands-on tasks, keeps the environment organized, and makes sure everyone is comfortable. Afterward, they gather feedback and adjust the class for a better learning experience.']},
#  {'number': 89,
#   'title': 'Home renovation',
#   'description': ['Sky and Taylor are renovating their home. Both take tasks—Sky handling demolition and Taylor focusing on rebuilding. Sky tears down old structures, removes debris, and preps surfaces for upgrades. Taylor installs new fixtures, paints walls, and lays flooring. Sky ensures proper disposal of materials, checks for structural stability, and clears space for renovations. Taylor measures dimensions, selects finishes, and refines details. They collaborate on design choices, balance aesthetics with function, and make adjustments as needed to complete their renovation successfully.']},
#  {'number': 90,
#   'title': 'Organizimg a local play',
#   'description': ['Jordan and Drew put on a local play. Both contribute—Jordan designing costumes and Drew managing lighting. Jordan researches period styles, selects fabrics, and tailors outfits to fit the cast. Drew programs lighting cues, adjusts intensity, and creates mood-enhancing effects. Jordan ensures each costume aligns with the character’s role, adds finishing touches, and oversees quick changes. Drew coordinates with the director, troubleshoots technical issues, and fine-tunes transitions. They work closely with the cast to ensure a seamless and visually stunning performance.']},
#  {'number': 91,
#   'title': 'Co-assisting a hospital ward',
#   'description': ['Morgan and Casey assist in a busy hospital ward. Both take roles—Morgan managing patient care and Casey handling medical records. Morgan checks vital signs, administers medications, and communicates with doctors. Casey updates charts, processes test results, and ensures documentation. Morgan monitors patient progress, responds to emergencies, and provides comfort. Casey schedules procedures, coordinates with departments, and maintains compliance with protocols. They collaborate to ensure smooth operations, efficient treatment, and high-quality patient care, working together to improve health outcomes.']},
#  {'number': 92,
#   'title': 'Developing a mobile application',
#   'description': ['Morgan and Casey are developing a new mobile application. Both share responsibilities—Morgan handling the user interface and Casey managing the backend. Morgan designs the layout, creates wireframes, and tests interactions, ensuring the app’s functionality is intuitive. Casey writes code, troubleshoots issues, ensures data security, and optimizes performance. They collaborate to integrate new features, refine design, and streamline the user experience. Morgan leads usability tests, while Casey implements updates. Together, they monitor feedback and continuously make improvements to create a seamless, user-friendly application.']},
#  {'number': 93,
#   'title': 'Co-Teaching a Class',
#   'description': ['Jordan and Taylor are co-teaching a class. Both take on distinct roles—Jordan leading discussions and Taylor managing activities. Jordan explains concepts, facilitates group conversations, and answers questions. Taylor prepares materials, organizes hands-on exercises, and ensures student engagement. They collaborate on lesson plans, adjust pacing based on student needs, and offer support individually. Jordan monitors student progress during lectures, while Taylor provides feedback during assignments. Together, they create an inclusive learning environment and assess students’ understanding, ensuring effective teaching outcomes.']},
#  {'number': 94,
#   'title': 'Co-writing a research paper',
#   'description': ['Blake and Riley work on a research paper. Both focus on different tasks—Blake gathering research and Riley writing the content. Blake searches academic journals, collects data, and synthesizes findings. Riley drafts the introduction, writes analysis sections, and ensures the paper’s clarity. They collaborate on outlining key points, revising drafts, and refining the methodology. Blake double-checks the references, while Riley ensures proper formatting and consistency. Together, they review the paper, revise the conclusions, and finalize it for submission, ensuring accuracy, quality, and coherence.']},
#  {'number': 95,
#   'title': 'Medical laboratory collaboration',
#   'description': ['Blake and Avery work together in a medical laboratory to conduct tests. Both have distinct roles—Blake handling sample collection and Avery analyzing results. Blake prepares specimens, labels samples, and ensures proper handling. Avery runs diagnostic tests, interprets data, and records findings. They collaborate to maintain lab equipment, verify accuracy, and troubleshoot any issues. Blake monitors quality control procedures, while Avery compiles reports and ensures compliance with health standards. Together, they work to provide accurate and timely results for patient care.']},
#  {'number': 96,
#   'title': 'Childcare',
#   'description': ["Blake and Riley share childcare duties at home. Both take on different roles—Blake managing daily routines and Riley handling activities. Blake prepares meals, ensures nap times, and oversees homework. Riley plans playdates, organizes educational games, and reads books. They communicate about children's needs, monitor progress, and ensure safety. Blake tracks health appointments and schedules, while Riley addresses emotional and social well-being. Together, they create a balanced environment by maintaining structure and providing fun, fostering a nurturing atmosphere for their children's development."]},
#  {'number': 97,
#   'title': 'Running  a farm',
#   'description': ['Blake and Morgan are running a small farm together. Both take on different responsibilities—Blake managing crops and Morgan tending to animals. Blake plants seeds, monitors growth, and harvests produce. Morgan feeds livestock, collects eggs, and ensures animal health. They work together to maintain equipment, repair fences, and plan seasonal tasks. Blake tracks inventory and markets produce, while Morgan focuses on breeding and caring for the animals. Together, they create a self-sustaining farm by balancing crop production with animal husbandry.']},
#  {'number': 98,
#   'title': 'Leading a book club',
#   'description': ['Morgan and Quinn lead a vibrant book club, with each taking on key responsibilities. Morgan is in charge of selecting books, researching titles, and organizing the reading schedule to ensure variety. While Morgan provides detailed summaries to enhance understanding, Quinn facilitates discussions by encouraging participation, moderating talks, and tracking key themes throughout the books. Together, they collaborate to adapt to the interests and preferences of club members, adjusting their approach to keep discussions lively, inclusive, and relevant to everyone’s reading experiences.']},
#  {'number': 99,
#   'title': 'Leading a construction project',
#   'description': ['Morgan and Taylor lead a construction project. Both take charge—Morgan overseeing the design and Taylor managing construction. Morgan works with architects, finalizes blueprints, and ensures the design aligns with community needs. Taylor coordinates labor, supervises contractors, and monitors the construction process. Morgan handles permits, safety regulations, and budget allocation, while Taylor ensures deadlines are met, materials are ordered, and quality is maintained. Together, they oversee the project’s completion, making adjustments as needed to stay on track and within budget.']},
#  {'number': 100,
#   'title': 'Managing a local delivery system',
#   'description': ['Morgan and Riley are managing a local delivery system. Both have key roles—Morgan handling logistics and Riley overseeing drivers. Morgan plans routes, tracks orders, and ensures timely deliveries. Riley recruits drivers, organizes schedules, and manages customer communication. Morgan monitors inventory, adjusts delivery zones, and coordinates with suppliers. Riley ensures proper documentation, resolves issues, and maintains driver performance. Together, they analyze customer feedback, refine processes, and optimize delivery efficiency, to improve service and reduce delivery times.']}]
